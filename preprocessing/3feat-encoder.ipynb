# %% [markdown]
# # Text & Image & Video Feature Extraction

# %%
import os
import numpy as np
import pandas as pd

# %%
os.chdir('data')
os.getcwd()
# Out:
# '/root/preprocessing/data'

# %% [markdown]
# ## Load text data

# %%
i_id, item_str = 'itemID', 'item'

file_path = './'
file_name = 'meta_MicroLens.csv'

meta_file = os.path.join(file_path, file_name)

df = pd.read_csv(meta_file)
df.sort_values(by=[i_id], inplace=True)

print('data loaded!')
print(f'shape: {df.shape}')

df[:3]
# Out:
# data loaded!
# shape: (19738, 4)
#        itemID   item                                              title  tags
# 9579        0   9580   the best place to destroy the most wonderful ...  Game
# 14630       1  14631   # King Glory national Service Dharma being sp...  Game
# 7314        2   7315   # King glory country serve Damo old table pla...  Game

# %%
title_na_df = df[df['title'].isnull()]
print(title_na_df.shape)

desc_na_df = df[df['tags'].isnull()]
print(desc_na_df.shape)
# Out:
# (0, 4)
# (0, 4)

# %%
df['title'] = df['title'].fillna(" ")
df['tags'] = df['tags'].fillna(" ")

# %%
# Since only the title feature is available, construct sentences using the title.
sentences = []

for i, row in df.iterrows():
    sen = row['title'] + ' ' + row['tags'] + ' '
    sen = sen.replace('\n', ' ')
    sentences.append(sen)

sentences[:10]
# Out:
# [' the best place to destroy the most wonderful team with the fastest speed Game ',
#  ' # King Glory national Service Dharma being sprayed vegetable is really like this Game ',
#  ' # King glory country serve Damo old table play Lv Bu Game ',
#  ' MC sees creatures that replicate? Raise an army of iron puppets for the village! Real Village Heroes # QuickHands My World # Myworld #MC  Game ',
#  " # King of Glory served Dharma hit the peak of ridicule. I'm back Game ",
#  ' this is a 2100 division robbery bureau Game ',
#  " campus weird talk: roommate Ajie's prank! # thrillsuspenseful # schoolyard Weirtalk Daily Sharing ",
#  '  Daily Sharing ',
#  ' made a big box of star cedars ❄️ handmade soap ~ The New Year also want to be like a small pine 🌲 hard and lucky life ✨ #Vlog daily # handmade soap cold soap Daily Sharing ',
#  ' too hard # assist Game ']

# %%
course_list = df[i_id].tolist()
assert course_list[-1] == len(course_list) -1

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

sentence_embeddings = model.encode(sentences)
print('text encoded!')

assert sentence_embeddings.shape[0] == df.shape[0]
np.save(os.path.join(file_path, 'text_feat.npy'), sentence_embeddings)
print('done!')
# Out:
# /root/miniconda3/lib/python3.8/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# text encoded!
# done!

# %%
sentence_embeddings[:10]
sentence_embeddings.shape
# Out:
# (19738, 384)

# %%
load_txt_feat = np.load('text_feat.npy', allow_pickle=True)
print(load_txt_feat.shape)
load_txt_feat[:10]
# Out:
# (19738, 384)
# array([[ 3.4294955e-02,  8.4141500e-02, -4.6296481e-02, ...,
#          5.9475612e-02,  5.2324805e-02,  1.5298225e-02],
#        [-4.8817385e-02,  2.5659388e-02, -4.2193025e-02, ...,
#         -8.7688394e-02,  1.8543907e-03, -6.9620837e-05],
#        [-1.1217424e-05,  3.7120316e-02, -4.7777954e-02, ...,
#         -2.2200752e-02, -3.2746003e-03, -5.9879858e-02],
#        ...,
#        [-5.6936350e-02,  2.4288543e-02,  6.9684954e-03, ...,
#          3.8671199e-02, -1.2934662e-01,  5.9208952e-02],
#        [-7.6627605e-02,  4.4511382e-02,  6.9404043e-02, ...,
#          9.6225264e-03, -1.0243885e-01,  8.3619624e-02],
#        [-2.0027051e-02, -4.3830775e-02,  9.6338410e-03, ...,
#          4.6530124e-02,  7.5272918e-03, -4.7684433e-03]], dtype=float32)

# %% [markdown]
# # Image encoder, use VIT

# %%
from transformers import ViTFeatureExtractor, ViTModel
import numpy as np
from PIL import Image
import pandas as pd
import torch
# Load the CSV file and sort by itemID.
df = pd.read_csv('meta_MicroLens.csv')
df.sort_values(by='itemID', inplace=True)
print(df.head())
# Out:
#        itemID   item                                              title  tags
# 9579        0   9580   the best place to destroy the most wonderful ...  Game
# 14630       1  14631   # King Glory national Service Dharma being sp...  Game
# 7314        2   7315   # King glory country serve Damo old table pla...  Game
# 1954        3   1955   MC sees creatures that replicate? Raise an ar...  Game
# 9942        4   9943   # King of Glory served Dharma hit the peak of...  Game

# %%
# Check if GPU is available, if so, set it as the default device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize the ViT feature extractor and model, and move them to the device
feature_extractor = ViTFeatureExtractor.from_pretrained('vit-base-patch16-224')
model = ViTModel.from_pretrained('vit-base-patch16-224').to(device)

def extract_features(image_path, feature_extractor, model, device):
    # Open and process the image
    image = Image.open(image_path)
    inputs = feature_extractor(images=image, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}  # Move inputs to GPU

    # Perform model inference on the GPU and extract features
    with torch.no_grad():
        outputs = model(**inputs)
    features = outputs.last_hidden_state[:, 0, :].cpu().detach().numpy()  # Move features back to CPU
    return features.squeeze()

# Preset the image directory path
images_dir = '/root/autodl-tmp/MicroLens-100k_covers'

# Extract features
features_list = []
for _, row in df.iterrows():
    item = row['item']
    image_path = f'{images_dir}/{item}.jpg'
    print(f"Processing item {item}.")
    try:
        features = extract_features(image_path, feature_extractor, model, device)
        features_list.append(features)
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        # For images that cannot be processed, you may need to add a placeholder or skip them

# Convert to numpy array and save
features_array = np.array(features_list)
np.save('image_feat.npy', features_array)

print('Image features extracted and saved!')
# Out:
# Using device: cuda
# /root/miniconda3/lib/python3.8/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# Some weights of ViTModel were not initialized from the model checkpoint at vit-base-patch16-224 and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Processing item 9580.
# Processing item 14631.
# Processing item 7315.
# Processing item 1955.
# Processing item 9943.
# Processing item 12077.
# Processing item 8411.
# Processing item 16821.
# Processing item 13832.
# Processing item 7771.
# Processing item 9973.
# Processing item 6763.
# Processing item 2550.
# Processing item 5266.
# Processing item 8316.
# Processing item 11733.
# Processing item 16425.
# Processing item 4253.
# Processing item 1148.
# Processing item 10589.
# Processing item 621.
# Processing item 11802.
# Processing item 14283.
# Processing item 18491.
# Processing item 14394.
# Processing item 5865.
# Processing item 18490.
# Processing item 3129.
# Processing item 14044.
# Processing item 11246.
# Processing item 5535.
# Processing item 18257.
# Processing item 11698.
# Processing item 15194.
# Processing item 19120.
# Processing item 9949.
# Processing item 18584.
# Processing item 12164.
# Processing item 10509.
# Processing item 14958.
# Processing item 11527.
# Processing item 12104.
# Processing item 12109.
# Processing item 1099.
# Processing item 7454.
# Processing item 5614.
# Processing item 12735.
# Processing item 4148.
# Processing item 13539.
# Processing item 4735.
# Processing item 8019.
# Processing item 2604.
# Processing item 9590.
# Processing item 4420.
# Processing item 4502.
# Processing item 5967.
# Processing item 9919.
# Processing item 1734.
# Processing item 11685.
# Processing item 4683.
# Processing item 17944.
# Processing item 19173.
# Processing item 15173.
# Processing item 2988.
# Processing item 6097.
# Processing item 11114.
# Processing item 10635.
# Processing item 19115.
# Processing item 13748.
# Processing item 3451.
# Processing item 17543.
# Processing item 16117.
# Processing item 17803.
# Processing item 414.
# Processing item 7285.
# Processing item 19482.
# Processing item 17652.
# Processing item 15876.
# Processing item 6957.
# Processing item 7362.
# Processing item 18054.
# Processing item 7060.
# Processing item 9365.
# Processing item 16467.
# Processing item 858.
# Processing item 2481.
# Processing item 10941.
# Processing item 8107.
# Processing item 2900.
# Processing item 10910.
# Processing item 10514.
# Processing item 4073.
# Processing item 18750.
# Processing item 1105.
# Processing item 17400.
# Processing item 17571.
# Processing item 1704.
# Processing item 7915.
# Processing item 14450.
# Processing item 7637.
# Processing item 17552.
# Processing item 14242.
# Processing item 13834.
# Processing item 15536.
# Processing item 6989.
# Processing item 10247.
# Processing item 9819.
# Processing item 14916.
# Processing item 19078.
# Processing item 15866.
# Processing item 5305.
# Processing item 10335.
# Processing item 17655.
# Processing item 11797.
# Processing item 12792.
# Processing item 18887.
# Processing item 4295.
# Processing item 8385.
# Processing item 13775.
# Processing item 18504.
# Processing item 11204.
# Processing item 1552.
# Processing item 10741.
# Processing item 13362.
# Processing item 6718.
# Processing item 17906.
# Processing item 12198.
# Processing item 6796.
# Processing item 19117.
# Processing item 8315.
# Processing item 15411.
# Processing item 1271.
# Processing item 1547.
# Processing item 11215.
# Processing item 3166.
# Processing item 14572.
# Processing item 12732.
# Processing item 16419.
# Processing item 1050.
# Processing item 606.
# Processing item 7998.
# Processing item 3619.
# Processing item 3386.
# Processing item 19029.
# Processing item 1457.
# Processing item 10539.
# Processing item 272.
# Processing item 15096.
# Processing item 8528.
# Processing item 16292.
# Processing item 4387.
# Processing item 3773.
# Processing item 17556.
# Processing item 10909.
# Processing item 5537.
# Processing item 10790.
# Processing item 10382.
# Processing item 8752.
# Processing item 1661.
# Processing item 8696.
# Processing item 15148.
# Processing item 17891.
# Processing item 12741.
# Processing item 9642.
# Processing item 4298.
# Processing item 1907.
# Processing item 19325.
# Processing item 19277.
# Processing item 17745.
# Processing item 10687.
# Processing item 5710.
# Processing item 15908.
# Processing item 8268.
# Processing item 12136.
# Processing item 13404.
# Processing item 4046.
# Processing item 14078.
# Processing item 13972.
# Processing item 5655.
# Processing item 17181.
# Processing item 1330.
# Processing item 5166.
# Processing item 14993.
# Processing item 8976.
# Processing item 17045.
# Processing item 17044.
# Processing item 2405.
# Processing item 1543.
# Processing item 917.
# Processing item 14043.
# Processing item 17207.
# Processing item 14469.
# Processing item 17101.
# Processing item 862.
# Processing item 16182.
# Processing item 10649.
# Processing item 9317.
# Processing item 2544.
# Processing item 6525.
# Processing item 14329.
# Processing item 6714.
# Processing item 5014.
# Processing item 15766.
# Processing item 17214.
# Processing item 735.
# Processing item 2181.
# Processing item 16360.
# Processing item 13921.
# Processing item 13804.
# Processing item 390.
# Processing item 12983.
# Processing item 8672.
# Processing item 14361.
# Processing item 2709.
# Processing item 1195.
# Processing item 2484.
# Processing item 11972.
# Processing item 15838.
# Processing item 17593.
# Processing item 1681.
# Processing item 9072.
# Processing item 726.
# Processing item 5417.
# Processing item 15926.
# Processing item 19309.
# Processing item 1240.
# Processing item 1586.
# Processing item 13378.
# Processing item 17419.
# Processing item 14874.
# Processing item 2387.
# Processing item 14030.
# Processing item 10328.
# Processing item 6784.
# Processing item 5133.
# Processing item 15570.
# Processing item 14003.
# Processing item 14678.
# Processing item 5648.
# Processing item 12522.
# Processing item 15968.
# Processing item 19530.
# Processing item 4266.
# Processing item 11443.
# Processing item 6243.
# Processing item 929.
# Processing item 6353.
# Processing item 9750.
# Processing item 18758.
# Processing item 15521.
# Processing item 11126.
# Processing item 7655.
# Processing item 12505.
# Processing item 8071.
# Processing item 3716.
# Processing item 3065.
# Processing item 13046.
# Processing item 15983.
# Processing item 4542.
# Processing item 17565.
# Processing item 14427.
# Processing item 18376.
# Processing item 5429.
# Processing item 1593.
# Processing item 19615.
# Processing item 11468.
# Processing item 7326.
# Processing item 8910.
# Processing item 4962.
# Processing item 13164.
# Processing item 15118.
# Processing item 10929.
# Processing item 2837.
# Processing item 628.
# Processing item 8260.
# Processing item 17930.
# Processing item 4448.
# Processing item 6375.
# Processing item 12421.
# Processing item 13898.
# Processing item 19420.
# Processing item 4419.
# Processing item 14040.
# Processing item 12376.
# Processing item 10360.
# Processing item 3441.
# Processing item 689.
# Processing item 2548.
# Processing item 7796.
# Processing item 16412.
# Processing item 14812.
# Processing item 17123.
# Processing item 10777.
# Processing item 4212.
# Processing item 7795.
# Processing item 12131.
# Processing item 480.
# Processing item 5375.
# Processing item 15547.
# Processing item 15135.
# Processing item 18844.
# Processing item 5438.
# Processing item 7894.
# Processing item 15606.
# Processing item 17845.
# Processing item 10504.
# Processing item 9345.
# Processing item 7736.
# Processing item 5229.
# Processing item 1789.
# Processing item 16381.
# Processing item 755.
# Processing item 2609.
# Processing item 2881.
# Processing item 12312.
# Processing item 16883.
# Processing item 2432.
# Processing item 17273.
# Processing item 3346.
# Processing item 1795.
# Processing item 2475.
# Processing item 14693.
# Processing item 5302.
# Processing item 8851.
# Processing item 12579.
# Processing item 5433.
# Processing item 681.
# Processing item 18437.
# Processing item 3509.
# Processing item 10413.
# Processing item 10774.
# Processing item 18107.
# Processing item 10260.
# Processing item 1388.
# Processing item 18267.
# Processing item 7689.
# Processing item 5683.
# Processing item 17856.
# Processing item 15690.
# Processing item 3311.
# Processing item 4276.
# Processing item 6527.
# Processing item 14211.
# Processing item 4400.
# Processing item 5792.
# Processing item 1631.
# Processing item 8482.
# Processing item 14664.
# Processing item 7447.
# Processing item 13113.
# Processing item 16873.
# Processing item 14913.
# Processing item 7354.
# Processing item 949.
# Processing item 9767.
# Processing item 2720.
# Processing item 15152.
# Processing item 5767.
# Processing item 17599.
# Processing item 18120.
# Processing item 18356.
# Processing item 17589.
# Processing item 16916.
# Processing item 4598.
# Processing item 11069.
# Processing item 10474.
# Processing item 9432.
# Processing item 17264.
# Processing item 17596.
# Processing item 18299.
# Processing item 7777.
# Processing item 14687.
# Processing item 8824.
# Processing item 10742.
# Processing item 3104.
# Processing item 18508.
# Processing item 11842.
# Processing item 29.
# Processing item 17482.
# Processing item 11087.
# Processing item 8449.
# Processing item 8161.
# Processing item 5344.
# Processing item 5546.
# Processing item 4306.
# Processing item 13754.
# Processing item 1038.
# Processing item 8723.
# Processing item 11782.
# Processing item 14452.
# Processing item 15428.
# Processing item 3529.
# Processing item 7137.
# Processing item 11093.
# Processing item 5262.
# Processing item 9202.
# Processing item 7279.
# Processing item 6161.
# Processing item 3591.
# Processing item 11098.
# Processing item 12510.
# Processing item 16642.
# Processing item 4058.
# Processing item 5790.
# Processing item 18297.
# Processing item 13043.
# Processing item 1768.
# Processing item 14943.
# Processing item 18791.
# Processing item 13425.
# Processing item 9389.
# Processing item 4496.
# Processing item 14150.
# Processing item 9096.
# Processing item 1971.
# Processing item 19361.
# Processing item 12375.
# Processing item 11222.
# Processing item 11961.
# Processing item 9722.
# Processing item 8993.
# Processing item 8173.
# Processing item 17646.
# Processing item 9843.
# Processing item 14447.
# Processing item 6291.
# Processing item 3872.
# Processing item 8714.
# Processing item 13472.
# Processing item 8623.
# Processing item 95.
# Processing item 14860.
# Processing item 18862.
# Processing item 874.
# Processing item 13047.
# Processing item 5396.
# Processing item 9243.
# Processing item 1324.
# Processing item 12556.
# Processing item 8825.
# Processing item 441.
# Processing item 15591.
# Processing item 18720.
# Processing item 16142.
# Processing item 16988.
# Processing item 16224.
# Processing item 5436.
# Processing item 6371.
# Processing item 1851.
# Processing item 15424.
# Processing item 9629.
# Processing item 7468.
# Processing item 19308.
# Processing item 16348.
# Processing item 8611.
# Processing item 4376.
# Processing item 2286.
# Processing item 8309.
# Processing item 14231.
# Processing item 12548.
# Processing item 608.
# Processing item 18422.
# Processing item 5019.
# Processing item 18806.
# Processing item 936.
# Processing item 9510.
# Processing item 16626.
# Processing item 4635.
# Processing item 12496.
# Processing item 6948.
# Processing item 10111.
# Processing item 17604.
# Processing item 9308.
# Processing item 3797.
# Processing item 17978.
# Processing item 5668.
# Processing item 16068.
# Processing item 5500.
# Processing item 14296.
# Processing item 10889.
# Processing item 13179.
# Processing item 134.
# Processing item 3865.
# Processing item 14965.
# Processing item 16206.
# Processing item 18181.
# Processing item 16650.
# Processing item 3071.
# Processing item 13372.
# Processing item 10884.
# Processing item 3383.
# Processing item 6896.
# Processing item 4859.
# Processing item 14222.
# Processing item 18623.
# Processing item 3011.
# Processing item 981.
# Processing item 635.
# Processing item 17145.
# Processing item 13001.
# Processing item 8274.
# Processing item 8943.
# Processing item 898.
# Processing item 12554.
# Processing item 12446.
# Processing item 1727.
# Processing item 10733.
# Processing item 17051.
# Processing item 18797.
# Processing item 12829.
# Processing item 10250.
# Processing item 13363.
# Processing item 17792.
# Processing item 8988.
# Processing item 12954.
# Processing item 17124.
# Processing item 427.
# Processing item 17448.
# Processing item 2169.
# Processing item 4658.
# Processing item 8903.
# Processing item 1730.
# Processing item 12860.
# Processing item 12799.
# Processing item 10141.
# Processing item 5993.
# Processing item 3891.
# Processing item 11765.
# Processing item 3208.
# Processing item 17138.
# Processing item 10208.
# Processing item 9511.
# Processing item 9506.
# Processing item 14615.
# Processing item 11912.
# Processing item 11092.
# Processing item 7269.
# Processing item 994.
# Processing item 7605.
# Processing item 3010.
# Processing item 18647.
# Processing item 18456.
# Processing item 18197.
# Processing item 2327.
# Processing item 4096.
# Processing item 1799.
# Processing item 10110.
# Processing item 3816.
# Processing item 15434.
# Processing item 18884.
# Processing item 8761.
# Processing item 7136.
# Processing item 8145.
# Processing item 1881.
# Processing item 13453.
# Processing item 3239.
# Processing item 15717.
# Processing item 2291.
# Processing item 11614.
# Processing item 14058.
# Processing item 8530.
# Processing item 10438.
# Processing item 17305.
# Processing item 3881.
# Processing item 3790.
# Processing item 13624.
# Processing item 3463.
# Processing item 17369.
# Processing item 16701.
# Processing item 32.
# Processing item 13268.
# Processing item 18938.
# Processing item 11499.
# Processing item 4150.
# Processing item 48.
# Processing item 2680.
# Processing item 17517.
# Processing item 14947.
# Processing item 7194.
# Processing item 4668.
# Processing item 15446.
# Processing item 17179.
# Processing item 895.
# Processing item 3638.
# Processing item 7838.
# Processing item 8221.
# Processing item 12681.
# Processing item 4478.
# Processing item 12600.
# Processing item 11838.
# Processing item 18622.
# Processing item 2123.
# Processing item 12515.
# Processing item 7990.
# Processing item 14250.
# Processing item 8809.
# Processing item 19132.
# Processing item 6992.
# Processing item 1788.
# Processing item 2424.
# Processing item 5738.
# Processing item 17266.
# Processing item 13853.
# Processing item 4378.
# Processing item 18874.
# Processing item 1147.
# Processing item 10987.
# Processing item 16792.
# Processing item 17418.
# Processing item 8189.
# Processing item 17817.
# Processing item 13919.
# Processing item 2749.
# Processing item 9960.
# Processing item 444.
# Processing item 17202.
# Processing item 16109.
# Processing item 10193.
# Processing item 5725.
# Processing item 19513.
# Processing item 15778.
# Processing item 6493.
# Processing item 2734.
# Processing item 13165.
# Processing item 13938.
# Processing item 10170.
# Processing item 12238.
# Processing item 15318.
# Processing item 15491.
# Processing item 9983.
# Processing item 3836.
# Processing item 14501.
# Processing item 15205.
# Processing item 14160.
# Processing item 1656.
# Processing item 13847.
# Processing item 6669.
# Processing item 8140.
# Processing item 16584.
# Processing item 139.
# Processing item 4860.
# Processing item 14837.
# Processing item 11095.
# Processing item 13566.
# Processing item 9976.
# Processing item 9883.
# Processing item 1486.
# Processing item 2012.
# Processing item 12739.
# Processing item 98.
# Processing item 8295.
# Processing item 19604.
# Processing item 16934.
# Processing item 11036.
# Processing item 12566.
# Processing item 1563.
# Processing item 2357.
# Processing item 8358.
# Processing item 7718.
# Processing item 11832.
# Processing item 4571.
# Processing item 14210.
# Processing item 18813.
# Processing item 1435.
# Processing item 8646.
# Processing item 7801.
# Processing item 4055.
# Processing item 16573.
# Processing item 13411.
# Processing item 14614.
# Processing item 2811.
# Processing item 2240.
# Processing item 3761.
# Processing item 16803.
# Processing item 13292.
# Processing item 5654.
# Processing item 15001.
# Processing item 18200.
# Processing item 14191.
# Processing item 14159.
# Processing item 3598.
# Processing item 15695.
# Processing item 9104.
# Processing item 5347.
# Processing item 2623.
# Processing item 14699.
# Processing item 18445.
# Processing item 1156.
# Processing item 2863.
# Processing item 12814.
# Processing item 8044.
# Processing item 320.
# Processing item 1039.
# Processing item 4173.
# Processing item 9129.
# Processing item 11268.
# Processing item 12948.
# Processing item 1205.
# Processing item 19673.
# Processing item 2597.
# Processing item 6520.
# Processing item 5926.
# Processing item 10681.
# Processing item 901.
# Processing item 2673.
# Processing item 12302.
# Processing item 3159.
# Processing item 14341.
# Processing item 1958.
# Processing item 7578.
# Processing item 5327.
# Processing item 16599.
# Processing item 8941.
# Processing item 6973.
# Processing item 15541.
# Processing item 3390.
# Processing item 9048.
# Processing item 3161.
# Processing item 1961.
# Processing item 16048.
# Processing item 2520.
# Processing item 2838.
# Processing item 10083.
# Processing item 12819.
# Processing item 2277.
# Processing item 2582.
# Processing item 8097.
# Processing item 13993.
# Processing item 8930.
# Processing item 9413.
# Processing item 13858.
# Processing item 10344.
# Processing item 12135.
# Processing item 16227.
# Processing item 4791.
# Processing item 4765.
# Processing item 16510.
# Processing item 15832.
# Processing item 18764.
# Processing item 18092.
# Processing item 8939.
# Processing item 11394.
# Processing item 13475.
# Processing item 13270.
# Processing item 13927.
# Processing item 16254.
# Processing item 2840.
# Processing item 9260.
# Processing item 19360.
# Processing item 15007.
# Processing item 2237.
# Processing item 13042.
# Processing item 17301.
# Processing item 6170.
# Processing item 9776.
# Processing item 4767.
# Processing item 6398.
# Processing item 17758.
# Processing item 12067.
# Processing item 4263.
# Processing item 15130.
# Processing item 16311.
# Processing item 129.
# Processing item 16148.
# Processing item 17107.
# Processing item 9443.
# Processing item 16601.
# Processing item 1009.
# Processing item 17485.
# Processing item 16228.
# Processing item 10708.
# Processing item 17336.
# Processing item 2679.
# Processing item 13128.
# Processing item 10262.
# Processing item 920.
# Processing item 3213.
# Processing item 97.
# Processing item 16185.
# Processing item 11199.
# Processing item 16686.
# Processing item 3070.
# Processing item 2193.
# Processing item 523.
# Processing item 738.
# Processing item 2524.
# Processing item 6668.
# Processing item 26.
# Processing item 19096.
# Processing item 17798.
# Processing item 2005.
# Processing item 11952.
# Processing item 15485.
# Processing item 6140.
# Processing item 15696.
# Processing item 7934.
# Processing item 1405.
# Processing item 18822.
# Processing item 113.
# Processing item 2213.
# Processing item 6509.
# Processing item 11118.
# Processing item 16974.
# Processing item 12011.
# Processing item 4175.
# Processing item 7453.
# Processing item 4020.
# Processing item 6867.
# Processing item 17662.
# Processing item 12823.
# Processing item 7439.
# Processing item 4709.
# Processing item 7314.
# Processing item 11197.
# Processing item 4525.
# Processing item 2364.
# Processing item 9743.
# Processing item 16793.
# Processing item 5034.
# Processing item 4826.
# Processing item 7113.
# Processing item 13243.
# Processing item 4682.
# Processing item 19314.
# Processing item 13255.
# Processing item 6409.
# Processing item 12504.
# Processing item 7244.
# Processing item 1914.
# Processing item 17945.
# Processing item 9494.
# Processing item 7676.
# Processing item 8999.
# Processing item 18159.
# Processing item 18792.
# Processing item 9727.
# Processing item 16403.
# Processing item 17356.
# Processing item 18619.
# Processing item 5667.
# Processing item 11238.
# Processing item 8935.
# Processing item 19060.
# Processing item 14337.
# Processing item 7473.
# Processing item 2682.
# Processing item 1991.
# Processing item 12688.
# Processing item 4642.
# Processing item 11586.
# Processing item 19254.
# Processing item 15343.
# Processing item 17577.
# Processing item 15100.
# Processing item 614.
# Processing item 3729.
# Processing item 16750.
# Processing item 360.
# Processing item 17373.
# Processing item 6154.
# Processing item 4483.
# Processing item 366.
# Processing item 9116.
# Processing item 3730.
# Processing item 19009.
# Processing item 16937.
# Processing item 18902.
# Processing item 4606.
# Processing item 12683.
# Processing item 11332.
# Processing item 7349.
# Processing item 11937.
# Processing item 15296.
# Processing item 7219.
# Processing item 18908.
# Processing item 3987.
# Processing item 3862.
# Processing item 17378.
# Processing item 9148.
# Processing item 4656.
# Processing item 13892.
# Processing item 5061.
# Processing item 2776.
# Processing item 11234.
# Processing item 2278.
# Processing item 18280.
# Processing item 6343.
# Processing item 1444.
# Processing item 17558.
# Processing item 17200.
# Processing item 18061.
# Processing item 15229.
# Processing item 16082.
# Processing item 9930.
# Processing item 4358.
# Processing item 5553.
# Processing item 11311.
# Processing item 18632.
# Processing item 5548.
# Processing item 7623.
# Processing item 7312.
# Processing item 16307.
# Processing item 5115.
# Processing item 15782.
# Processing item 18072.
# Processing item 18766.
# Processing item 8015.
# Processing item 11803.
# Processing item 11402.
# Processing item 12355.
# Processing item 10169.
# Processing item 312.
# Processing item 18898.
# Processing item 7525.
# Processing item 13215.
# Processing item 8289.
# Processing item 13616.
# Processing item 3532.
# Processing item 6969.
# Processing item 7531.
# Processing item 698.
# Processing item 5411.
# Processing item 13870.
# Processing item 11619.
# Processing item 8622.
# Processing item 8665.
# Processing item 4183.
# Processing item 3574.
# Processing item 3.
# Processing item 173.
# Processing item 5950.
# Processing item 4086.
# Processing item 15300.
# Processing item 15423.
# Processing item 14960.
# Processing item 16899.
# Processing item 1935.
# Processing item 1034.
# Processing item 4430.
# Processing item 1113.
# Processing item 13928.
# Processing item 15346.
# Processing item 5271.
# Processing item 9193.
# Processing item 17442.
# Processing item 557.
# Processing item 15715.
# Processing item 17404.
# Processing item 55.
# Processing item 17489.
# Processing item 1785.
# Processing item 17445.
# Processing item 6849.
# Processing item 15996.
# Processing item 457.
# Processing item 2460.
# Processing item 1765.
# Processing item 583.
# Processing item 7874.
# Processing item 7467.
# Processing item 14763.
# Processing item 15928.
# Processing item 343.
# Processing item 9298.
# Processing item 6406.
# Processing item 5283.
# Processing item 11099.
# Processing item 2754.
# Processing item 2374.
# Processing item 16753.
# Processing item 13184.
# Processing item 16858.
# Processing item 4097.
# Processing item 19658.
# Processing item 16370.
# Processing item 17271.
# Processing item 7168.
# Processing item 15035.
# Processing item 1511.
# Processing item 11884.
# Processing item 14229.
# Processing item 10944.
# Processing item 4748.
# Processing item 10177.
# Processing item 15946.
# Processing item 2861.
# Processing item 658.
# Processing item 9024.
# Processing item 5498.
# Processing item 171.
# Processing item 2375.
# Processing item 5679.
# Processing item 16583.
# Processing item 14072.
# Processing item 18002.
# Processing item 9479.
# Processing item 12050.
# Processing item 4510.
# Processing item 9120.
# Processing item 11974.
# Processing item 3091.
# Processing item 3191.
# Processing item 2877.
# Processing item 19335.
# Processing item 2133.
# Processing item 14876.
# Processing item 13610.
# Processing item 10767.
# Processing item 13202.
# Processing item 4584.
# Processing item 4012.
# Processing item 3317.
# Processing item 1143.
# Processing item 4575.
# Processing item 19479.
# Processing item 17585.
# Processing item 2035.
# Processing item 11013.
# Processing item 5632.
# Processing item 2868.
# Processing item 13145.
# Processing item 3212.
# Processing item 15735.
# Processing item 9692.
# Processing item 11849.
# Processing item 4644.
# Processing item 18810.
# Processing item 19170.
# Processing item 5604.
# Processing item 1598.
# Processing item 10515.
# Processing item 12728.
# Processing item 18930.
# Processing item 18523.
# Processing item 8195.
# Processing item 3599.
# Processing item 14995.
# Processing item 5623.
# Processing item 11261.
# Processing item 15480.
# Processing item 3801.
# Processing item 1409.
# Processing item 10421.
# Processing item 13374.
# Processing item 10004.
# Processing item 13260.
# Processing item 5162.
# Processing item 14945.
# Processing item 4453.
# Processing item 6922.
# Processing item 4084.
# Processing item 12643.
# Processing item 17444.
# Processing item 6262.
# Processing item 5378.
# Processing item 7123.
# Processing item 18137.
# Processing item 14867.
# Processing item 375.
# Processing item 11111.
# Processing item 16342.
# Processing item 4066.
# Processing item 16810.
# Processing item 11344.
# Processing item 39.
# Processing item 8426.
# Processing item 8985.
# Processing item 14487.
# Processing item 12995.
# Processing item 2505.
# Processing item 7916.
# Processing item 3925.
# Processing item 9213.
# Processing item 9177.
# Processing item 11480.
# Processing item 13120.
# Processing item 6171.
# Processing item 9804.
# Processing item 12284.
# Processing item 624.
# Processing item 4720.
# Processing item 3970.
# Processing item 3464.
# Processing item 15126.
# Processing item 19250.
# Processing item 12126.
# Processing item 10119.
# Processing item 12798.
# Processing item 10861.
# Processing item 7221.
# Processing item 3226.
# Processing item 9368.
# Processing item 8208.
# Processing item 2721.
# Processing item 11451.
# Processing item 4959.
# Processing item 12848.
# Processing item 5927.
# Processing item 425.
# Processing item 14877.
# Processing item 12784.
# Processing item 4961.
# Processing item 6723.
# Processing item 7014.
# Processing item 4356.
# Processing item 16604.
# Processing item 8830.
# Processing item 6388.
# Processing item 12448.
# Processing item 8982.
# Processing item 6287.
# Processing item 10937.
# Processing item 2827.
# Processing item 3042.
# Processing item 19602.
# Processing item 5539.
# Processing item 4182.
# Processing item 6937.
# Processing item 9748.
# Processing item 1729.
# Processing item 13481.
# Processing item 17510.
# Processing item 803.
# Processing item 8607.
# Processing item 4783.
# Processing item 7365.
# Processing item 1276.
# Processing item 17470.
# Processing item 16007.
# Processing item 968.
# Processing item 14300.
# Processing item 14496.
# Processing item 15861.
# Processing item 6730.
# Processing item 3199.
# Processing item 3942.
# Processing item 11104.
# Processing item 14618.
# Processing item 16865.
# Processing item 13325.
# Processing item 4840.
# Processing item 11483.
# Processing item 6063.
# Processing item 6257.
# Processing item 17812.
# Processing item 7046.
# Processing item 860.
# Processing item 3825.
# Processing item 4732.
# Processing item 3421.
# Processing item 13827.
# Processing item 16439.
# Processing item 8688.
# Processing item 392.
# Processing item 18295.
# Processing item 19209.
# Processing item 16097.
# Processing item 18187.
# Processing item 5066.
# Processing item 3853.
# Processing item 8402.
# Processing item 2057.
# Processing item 4628.
# Processing item 2684.
# Processing item 13013.
# Processing item 18144.
# Processing item 7697.
# Processing item 2715.
# Processing item 14444.
# Processing item 16293.
# Processing item 12998.
# Processing item 1016.
# Processing item 17730.
# Processing item 2656.
# Processing item 12019.
# Processing item 14247.
# Processing item 15389.
# Processing item 3203.
# Processing item 7895.
# Processing item 4111.
# Processing item 18352.
# Processing item 9340.
# Processing item 3875.
# Processing item 9197.
# Processing item 15407.
# Processing item 11931.
# Processing item 1532.
# Processing item 19458.
# Processing item 14382.
# Processing item 19711.
# Processing item 8888.
# Processing item 13553.
# Processing item 6964.
# Processing item 5653.
# Processing item 9799.
# Processing item 3249.
# Processing item 12523.
# Processing item 1510.
# Processing item 12551.
# Processing item 19303.
# Processing item 7450.
# Processing item 17126.
# Processing item 5524.
# Processing item 11450.
# Processing item 17282.
# Processing item 8132.
# Processing item 1693.
# Processing item 4771.
# Processing item 1337.
# Processing item 388.
# Processing item 2641.
# Processing item 11824.
# Processing item 15395.
# Processing item 6523.
# Processing item 6476.
# Processing item 14849.
# Processing item 1767.
# Processing item 10067.
# Processing item 15619.
# Processing item 8445.
# Processing item 3040.
# Processing item 15568.
# Processing item 5558.
# Processing item 9056.
# Processing item 1811.
# Processing item 12834.
# Processing item 7355.
# Processing item 5603.
# Processing item 13199.
# Processing item 8913.
# Processing item 7979.
# Processing item 18454.
# Processing item 14022.
# Processing item 12942.
# Processing item 3685.
# Processing item 15794.
# Processing item 18739.
# Processing item 2209.
# Processing item 18725.
# Processing item 12803.
# Processing item 8963.
# Processing item 17136.
# Processing item 1989.
# Processing item 11034.
# Processing item 5920.
# Processing item 17128.
# Processing item 5936.
# Processing item 7384.
# Processing item 1773.
# Processing item 17018.
# Processing item 16075.
# Processing item 6329.
# Processing item 13275.
# Processing item 338.
# Processing item 6139.
# Processing item 15753.
# Processing item 1083.
# Processing item 1699.
# Processing item 7305.
# Processing item 11572.
# Processing item 1564.
# Processing item 12938.
# Processing item 7903.
# Processing item 6289.
# Processing item 16960.
# Processing item 9607.
# Processing item 7551.
# Processing item 12926.
# Processing item 12908.
# Processing item 15396.
# Processing item 12806.
# Processing item 16747.
# Processing item 7093.
# Processing item 19669.
# Processing item 18468.
# Processing item 2453.
# Processing item 14526.
# Processing item 16862.
# Processing item 6394.
# Processing item 15293.
# Processing item 14840.
# Processing item 3211.
# Processing item 9654.
# Processing item 15179.
# Processing item 8718.
# Processing item 13895.
# Processing item 12278.
# Processing item 8557.
# Processing item 15462.
# Processing item 11528.
# Processing item 8334.
# Processing item 12062.
# Processing item 133.
# Processing item 15447.
# Processing item 10048.
# Processing item 3647.
# Processing item 14930.
# Processing item 9247.
# Processing item 18483.
# Processing item 19001.
# Processing item 12831.
# Processing item 7341.
# Processing item 8222.
# Processing item 4645.
# Processing item 11694.
# Processing item 14793.
# Processing item 9616.
# Processing item 8496.
# Processing item 12750.
# Processing item 15664.
# Processing item 6540.
# Processing item 19613.
# Processing item 520.
# Processing item 6685.
# Processing item 11080.
# Processing item 15569.
# Processing item 10094.
# Processing item 817.
# Processing item 9180.
# Processing item 6558.
# Processing item 17189.
# Processing item 4323.
# Processing item 9677.
# Processing item 18886.
# Processing item 16026.
# Processing item 18519.
# Processing item 18627.
# Processing item 14086.
# Processing item 19444.
# Processing item 1578.
# Processing item 5445.
# Processing item 10952.
# Processing item 7888.
# Processing item 11050.
# Processing item 10225.
# Processing item 16089.
# Processing item 13248.
# Processing item 8658.
# Processing item 14376.
# Processing item 6324.
# Processing item 8050.
# Processing item 10065.
# Processing item 702.
# Processing item 13911.
# Processing item 19342.
# Processing item 2136.
# Processing item 10414.
# Processing item 7699.
# Processing item 10616.
# Processing item 7746.
# Processing item 16103.
# Processing item 16147.
# Processing item 11960.
# Processing item 3845.
# Processing item 1495.
# Processing item 13558.
# Processing item 2135.
# Processing item 5763.
# Processing item 15337.
# Processing item 15575.
# Processing item 3848.
# Processing item 9887.
# Processing item 17557.
# Processing item 2506.
# Processing item 4245.
# Processing item 6352.
# Processing item 16580.
# Processing item 580.
# Processing item 5011.
# Processing item 12929.
# Processing item 439.
# Processing item 12354.
# Processing item 6605.
# Processing item 13665.
# Processing item 3749.
# Processing item 18313.
# Processing item 10621.
# Processing item 2120.
# Processing item 8002.
# Processing item 2714.
# Processing item 3983.
# Processing item 3067.
# Processing item 18817.
# Processing item 6830.
# Processing item 13194.
# Processing item 9498.
# Processing item 8414.
# Processing item 4956.
# Processing item 1803.
# Processing item 2690.
# Processing item 10086.
# Processing item 8535.
# Processing item 3657.
# Processing item 4784.
# Processing item 9391.
# Processing item 1306.
# Processing item 7261.
# Processing item 12466.
# Processing item 14881.
# Processing item 1349.
# Processing item 16154.
# Processing item 4586.
# Processing item 2600.
# Processing item 2494.
# Processing item 3979.
# Processing item 6258.
# Processing item 3754.
# Processing item 7670.
# Processing item 18714.
# Processing item 6179.
# Processing item 1488.
# Processing item 12854.
# Processing item 3961.
# Processing item 13129.
# Processing item 3227.
# Processing item 13370.
# Processing item 10969.
# Processing item 7101.
# Processing item 4166.
# Processing item 4734.
# Processing item 1880.
# Processing item 3497.
# Processing item 14717.
# Processing item 3585.
# Processing item 12216.
# Processing item 13525.
# Processing item 16996.
# Processing item 14236.
# Processing item 10242.
# Processing item 11563.
# Processing item 5031.
# Processing item 7139.
# Processing item 6151.
# Processing item 7855.
# Processing item 1167.
# Processing item 16770.
# Processing item 14127.
# Processing item 6431.
# Processing item 17741.
# Processing item 11578.
# Processing item 12095.
# Processing item 11022.
# Processing item 19681.
# Processing item 1975.
# Processing item 19393.
# Processing item 13089.
# Processing item 7001.
# Processing item 18413.
# Processing item 6041.
# Processing item 5984.
# Processing item 17847.
# Processing item 2425.
# Processing item 12367.
# Processing item 7770.
# Processing item 5080.
# Processing item 9908.
# Processing item 8859.
# Processing item 6930.
# Processing item 12021.
# Processing item 15374.
# Processing item 15294.
# Processing item 16718.
# Processing item 14090.
# Processing item 4203.
# Processing item 495.
# Processing item 18698.
# Processing item 17888.
# Processing item 9421.
# Processing item 6049.
# Processing item 8795.
# Processing item 4623.
# Processing item 5808.
# Processing item 16967.
# Processing item 14348.
# Processing item 16025.
# Processing item 2020.
# Processing item 836.
# Processing item 10506.
# Processing item 7153.
# Processing item 16784.
# Processing item 17193.
# Processing item 15855.
# Processing item 2263.
# Processing item 8213.
# Processing item 5336.
# Processing item 15837.
# Processing item 19391.
# Processing item 10361.
# Processing item 9753.
# Processing item 11639.
# Processing item 13627.
# Processing item 8808.
# Processing item 2075.
# Processing item 18986.
# Processing item 6791.
# Processing item 11165.
# Processing item 13201.
# Processing item 6202.
# Processing item 13728.
# Processing item 7823.
# Processing item 4692.
# Processing item 13942.
# Processing item 14520.
# Processing item 7897.
# Processing item 777.
# Processing item 6118.
# Processing item 1338.
# Processing item 19672.
# Processing item 4471.
# Processing item 1196.
# Processing item 4128.
# Processing item 16948.
# Processing item 3646.
# Processing item 2580.
# Processing item 18896.
# Processing item 16486.
# Processing item 16221.
# Processing item 19722.
# Processing item 521.
# Processing item 7424.
# Processing item 14439.
# Processing item 12092.
# Processing item 17527.
# Processing item 182.
# Processing item 532.
# Processing item 19389.
# Processing item 11391.
# Processing item 18837.
# Processing item 11627.
# Processing item 17388.
# Processing item 9731.
# Processing item 13598.
# Processing item 19090.
# Processing item 18899.
# Processing item 17661.
# Processing item 18590.
# Processing item 19231.
# Processing item 10460.
# Processing item 3310.
# Processing item 14862.
# Processing item 1190.
# Processing item 5507.
# Processing item 4599.
# Processing item 12100.
# Processing item 8215.
# Processing item 16992.
# Processing item 10543.
# Processing item 12727.
# Processing item 4322.
# Processing item 13249.
# Processing item 3442.
# Processing item 9016.
# Processing item 13098.
# Processing item 11214.
# Processing item 18684.
# Processing item 8139.
# Processing item 8249.
# Processing item 16969.
# Processing item 4290.
# Processing item 14635.
# Processing item 5824.
# Processing item 8431.
# Processing item 6620.
# Processing item 14500.
# Processing item 1085.
# Processing item 1607.
# Processing item 18499.
# Processing item 14931.
# Processing item 5541.
# Processing item 9608.
# Processing item 12036.
# Processing item 10850.
# Processing item 14694.
# Processing item 11390.
# Processing item 5191.
# Processing item 2512.
# Processing item 17074.
# Processing item 16605.
# Processing item 16472.
# Processing item 14939.
# Processing item 18163.
# Processing item 5385.
# Processing item 8464.
# Processing item 13160.
# Processing item 4318.
# Processing item 5177.
# Processing item 11672.
# Processing item 8815.
# Processing item 10659.
# Processing item 7580.
# Processing item 11551.
# Processing item 2856.
# Processing item 9518.
# Processing item 5239.
# Processing item 13672.
# Processing item 2069.
# Processing item 5594.
# Processing item 17308.
# Processing item 9468.
# Processing item 8684.
# Processing item 1918.
# Processing item 5726.
# Processing item 11701.
# Processing item 18630.
# Processing item 8969.
# Processing item 9906.
# Processing item 7740.
# Processing item 16982.
# Processing item 546.
# Processing item 14868.
# Processing item 13546.
# Processing item 11232.
# Processing item 5501.
# Processing item 11565.
# Processing item 19585.
# Processing item 16043.
# Processing item 3648.
# Processing item 7794.
# Processing item 12894.
# Processing item 14976.
# Processing item 1395.
# Processing item 7709.
# Processing item 18496.
# Processing item 18290.
# Processing item 4248.
# Processing item 16355.
# Processing item 6719.
# Processing item 8229.
# Processing item 556.
# Processing item 5600.
# Processing item 15580.
# Processing item 17199.
# Processing item 6797.
# Processing item 16507.
# Processing item 2002.
# Processing item 18596.
# Processing item 3629.
# Processing item 3609.
# Processing item 19176.
# Processing item 11800.
# Processing item 6484.
# Processing item 8105.
# Processing item 6393.
# Processing item 7846.
# Processing item 4336.
# Processing item 14524.
# Processing item 10639.
# Processing item 1044.
# Processing item 5297.
# Processing item 19030.
# Processing item 10538.
# Processing item 1573.
# Processing item 13788.
# Processing item 2649.
# Processing item 6941.
# Processing item 4486.
# Processing item 1031.
# Processing item 865.
# Processing item 16390.
# Processing item 8846.
# Processing item 12257.
# Processing item 12112.
# Processing item 6487.
# Processing item 5930.
# Processing item 12676.
# Processing item 16476.
# Processing item 1810.
# Processing item 18334.
# Processing item 11203.
# Processing item 19166.
# Processing item 14281.
# Processing item 15440.
# Processing item 12710.
# Processing item 6955.
# Processing item 9875.
# Processing item 3282.
# Processing item 15700.
# Processing item 15683.
# Processing item 9327.
# Processing item 13479.
# Processing item 708.
# Processing item 692.
# Processing item 8090.
# Processing item 14062.
# Processing item 8101.
# Processing item 13070.
# Processing item 4171.
# Processing item 4844.
# Processing item 7268.
# Processing item 5008.
# Processing item 3228.
# Processing item 3514.
# Processing item 853.
# Processing item 12379.
# Processing item 4413.
# Processing item 8553.
# Processing item 7947.
# Processing item 5817.
# Processing item 1265.
# Processing item 12618.
# Processing item 13985.
# Processing item 13936.
# Processing item 18621.
# Processing item 13575.
# Processing item 14591.
# Processing item 9285.
# Processing item 2350.
# Processing item 1536.
# Processing item 686.
# Processing item 9533.
# Processing item 15942.
# Processing item 12825.
# Processing item 18451.
# Processing item 10897.
# Processing item 16658.
# Processing item 8822.
# Processing item 5889.
# Processing item 1967.
# Processing item 6712.
# Processing item 12280.
# Processing item 13011.
# Processing item 17594.
# Processing item 230.
# Processing item 17774.
# Processing item 12617.
# Processing item 10844.
# Processing item 10403.
# Processing item 13779.
# Processing item 2254.
# Processing item 6958.
# Processing item 19400.
# Processing item 14907.
# Processing item 770.
# Processing item 10364.
# Processing item 1509.
# Processing item 10443.
# Processing item 8427.
# Processing item 281.
# Processing item 17440.
# Processing item 7204.
# Processing item 7165.
# Processing item 2448.
# Processing item 2317.
# Processing item 4249.
# Processing item 8537.
# Processing item 4402.
# Processing item 4561.
# Processing item 10789.
# Processing item 16041.
# Processing item 15531.
# Processing item 8617.
# Processing item 1274.
# Processing item 16817.
# Processing item 1922.
# Processing item 12712.
# Processing item 12571.
# Processing item 992.
# Processing item 4992.
# Processing item 11702.
# Processing item 11392.
# Processing item 1518.
# Processing item 9127.
# Processing item 6042.
# Processing item 14230.
# Processing item 766.
# Processing item 6134.
# Processing item 9786.
# Processing item 9086.
# Processing item 7264.
# Processing item 13535.
# Processing item 15230.
# Processing item 8345.
# Processing item 9950.
# Processing item 11657.
# Processing item 5050.
# Processing item 13312.
# Processing item 16824.
# Processing item 3447.
# Processing item 7205.
# Processing item 18162.
# Processing item 567.
# Processing item 13682.
# Processing item 578.
# Processing item 12335.
# Processing item 9142.
# Processing item 18415.
# Processing item 11414.
# Processing item 16180.
# Processing item 3110.
# Processing item 19665.
# Processing item 5902.
# Processing item 518.
# Processing item 45.
# Processing item 6920.
# Processing item 2433.
# Processing item 187.
# Processing item 14358.
# Processing item 3164.
# Processing item 1022.
# Processing item 709.
# Processing item 17078.
# Processing item 1497.
# Processing item 2878.
# Processing item 3404.
# Processing item 13097.
# Processing item 9036.
# Processing item 3297.
# Processing item 4177.
# Processing item 2733.
# Processing item 18059.
# Processing item 5734.
# Processing item 8066.
# Processing item 4152.
# Processing item 4155.
# Processing item 18111.
# Processing item 1226.
# Processing item 12662.
# Processing item 6045.
# Processing item 14056.
# Processing item 16202.
# Processing item 4948.
# Processing item 18511.
# Processing item 16481.
# Processing item 1126.
# Processing item 10145.
# Processing item 15285.
# Processing item 1146.
# Processing item 13676.
# Processing item 14963.
# Processing item 18782.
# Processing item 8797.
# Processing item 15033.
# Processing item 16523.
# Processing item 8479.
# Processing item 3520.
# Processing item 16001.
# Processing item 10477.
# Processing item 16790.
# Processing item 10373.
# Processing item 14357.
# Processing item 8115.
# Processing item 5764.
# Processing item 2694.
# Processing item 3654.
# Processing item 8699.
# Processing item 5872.
# Processing item 1863.
# Processing item 2696.
# Processing item 17087.
# Processing item 18546.
# Processing item 12706.
# Processing item 14550.
# Processing item 5665.
# Processing item 19733.
# Processing item 9690.
# Processing item 10772.
# Processing item 9713.
# Processing item 9951.
# Processing item 11380.
# Processing item 6778.
# Processing item 110.
# Processing item 15904.
# Processing item 12502.
# Processing item 16665.
# Processing item 15622.
# Processing item 405.
# Processing item 1668.
# Processing item 13195.
# Processing item 12843.
# Processing item 47.
# Processing item 17952.
# Processing item 5091.
# Processing item 10605.
# Processing item 9656.
# Processing item 1696.
# Processing item 2456.
# Processing item 8370.
# Processing item 14214.
# Processing item 966.
# Processing item 1181.
# Processing item 13797.
# Processing item 9925.
# Processing item 4828.
# Processing item 3488.
# Processing item 13821.
# Processing item 11084.
# Processing item 9503.
# Processing item 7792.
# Processing item 8397.
# Processing item 18387.
# Processing item 2843.
# Processing item 9889.
# Processing item 11996.
# Processing item 16728.
# Processing item 9563.
# Processing item 15641.
# Processing item 9764.
# Processing item 13914.
# Processing item 19401.
# Processing item 19135.
# Processing item 18648.
# Processing item 12888.
# Processing item 11716.
# Processing item 12156.
# Processing item 3201.
# Processing item 1228.
# Processing item 12175.
# Processing item 7726.
# Processing item 9937.
# Processing item 12331.
# Processing item 4099.
# Processing item 10341.
# Processing item 14372.
# Processing item 5394.
# Processing item 6451.
# Processing item 18391.
# Processing item 13470.
# Processing item 8330.
# Processing item 14736.
# Processing item 17960.
# Processing item 7188.
# Processing item 4714.
# Processing item 8012.
# Processing item 7143.
# Processing item 18471.
# Processing item 14425.
# Processing item 14539.
# Processing item 14141.
# Processing item 19691.
# Processing item 6789.
# Processing item 8879.
# Processing item 9095.
# Processing item 17011.
# Processing item 1224.
# Processing item 9136.
# Processing item 6859.
# Processing item 5240.
# Processing item 9879.
# Processing item 3565.
# Processing item 1236.
# Processing item 10713.
# Processing item 4597.
# Processing item 12540.
# Processing item 15744.
# Processing item 14603.
# Processing item 7299.
# Processing item 12840.
# Processing item 11262.
# Processing item 14794.
# Processing item 70.
# Processing item 15276.
# Processing item 8650.
# Processing item 3190.
# Processing item 16618.
# Processing item 14306.
# Processing item 9763.
# Processing item 15786.
# Processing item 10258.
# Processing item 8298.
# Processing item 3962.
# Processing item 16426.
# Processing item 9977.
# Processing item 15050.
# Processing item 8476.
# Processing item 14015.
# Processing item 18154.
# Processing item 537.
# Processing item 9812.
# Processing item 8196.
# Processing item 4755.
# Processing item 5511.
# Processing item 11844.
# Processing item 3953.
# Processing item 16595.
# Processing item 6888.
# Processing item 2794.
# Processing item 4052.
# Processing item 4165.
# Processing item 12868.
# Processing item 2125.
# Processing item 4106.
# Processing item 9275.
# Processing item 13061.
# Processing item 4126.
# Processing item 9462.
# Processing item 13595.
# Processing item 1093.
# Processing item 2319.
# Processing item 2408.
# Processing item 6549.
# Processing item 14103.
# Processing item 1355.
# Processing item 16959.
# Processing item 16745.
# Processing item 16290.
# Processing item 2084.
# Processing item 18393.
# Processing item 6350.
# Processing item 14961.
# Processing item 1676.
# Processing item 7277.
# Processing item 10846.
# Processing item 10817.
# Processing item 4498.
# Processing item 15157.
# Processing item 11019.
# Processing item 3965.
# Processing item 5591.
# Processing item 3570.
# Processing item 19163.
# Processing item 8670.
# Processing item 15974.
# Processing item 7187.
# Processing item 971.
# Processing item 12682.
# Processing item 12459.
# Processing item 7626.
# Processing item 17825.
# Processing item 4102.
# Processing item 13774.
# Processing item 483.
# Processing item 3189.
# Processing item 6222.
# Processing item 6244.
# Processing item 12230.
# Processing item 14805.
# Processing item 906.
# Processing item 7226.
# Processing item 8305.
# Processing item 7851.
# Processing item 16150.
# Processing item 17600.
# Processing item 2058.
# Processing item 8700.
# Processing item 16628.
# Processing item 1077.
# Processing item 1018.
# Processing item 487.
# Processing item 4799.
# Processing item 17833.
# Processing item 8971.
# Processing item 2842.
# Processing item 17595.
# Processing item 12096.
# Processing item 2532.
# Processing item 19076.
# Processing item 16013.
# Processing item 12832.
# Processing item 6423.
# Processing item 6706.
# Processing item 7993.
# Processing item 7332.
# Processing item 4724.
# Processing item 11401.
# Processing item 6573.
# Processing item 1772.
# Processing item 4789.
# Processing item 19350.
# Processing item 4657.
# Processing item 19378.
# Processing item 13250.
# Processing item 7028.
# Processing item 14711.
# Processing item 15682.
# Processing item 2292.
# Processing item 15638.
# Processing item 3076.
# Processing item 885.
# Processing item 8679.
# Processing item 7594.
# Processing item 1273.
# Processing item 9278.
# Processing item 12933.
# Processing item 6096.
# Processing item 18274.
# Processing item 6901.
# Processing item 16265.
# Processing item 9648.
# Processing item 4878.
# Processing item 10576.
# Processing item 7389.
# Processing item 5727.
# Processing item 4983.
# Processing item 13635.
# Processing item 12414.
# Processing item 16315.
# Processing item 1272.
# Processing item 17559.
# Processing item 9027.
# Processing item 15537.
# Processing item 7978.
# Processing item 15358.
# Processing item 4146.
# Processing item 7408.
# Processing item 10677.
# Processing item 16166.
# Processing item 10656.
# Processing item 14700.
# Processing item 14873.
# Processing item 10781.
# Processing item 16760.
# Processing item 3423.
# Processing item 17782.
# Processing item 2274.
# Processing item 9429.
# Processing item 17243.
# Processing item 7727.
# Processing item 3904.
# Processing item 18586.
# Processing item 3268.
# Processing item 876.
# Processing item 10457.
# Processing item 16904.
# Processing item 364.
# Processing item 8585.
# ...
# Processing item 13012.
# Processing item 15114.
# Processing item 8047.
# Processing item 9582.
# Processing item 8135.
# Processing item 2659.
# Processing item 2936.
# Processing item 3649.
# Processing item 14338.
# Processing item 9121.
# Processing item 1212.
# Processing item 14053.
# Processing item 17058.
# Processing item 14234.
# Processing item 5322.
# Processing item 16287.
# Processing item 4779.
# Processing item 6116.
# Processing item 18788.
# Processing item 10726.
# Processing item 13733.
# Processing item 1705.
# Processing item 10904.
# Processing item 3948.
# Processing item 773.
# Processing item 15397.
# Processing item 6081.
# Processing item 9195.
# Processing item 3660.
# Processing item 13845.
# Processing item 4283.
# Processing item 7185.
# Processing item 3771.
# Processing item 5086.
# Processing item 11555.
# Processing item 8577.
# Processing item 564.
# Processing item 14551.
# Processing item 6381.
# Processing item 8673.
# Processing item 4946.
# Processing item 43.
# Processing item 18436.
# Processing item 2611.
# Processing item 13110.
# Processing item 15992.
# Processing item 8678.
# Processing item 10648.
# Processing item 2630.
# Processing item 13903.
# Processing item 8793.
# Processing item 3027.
# Processing item 11419.
# Processing item 19180.
# Processing item 6109.
# Processing item 6772.
# Processing item 16406.
# Processing item 5134.
# Processing item 2903.
# Processing item 54.
# Processing item 3847.
# Processing item 8894.
# Processing item 4480.
# Processing item 2222.
# Processing item 2992.
# Processing item 4818.
# Processing item 2313.
# Processing item 14858.
# Processing item 12191.
# Processing item 288.
# Processing item 16991.
# Processing item 4821.
# Processing item 9318.
# Processing item 12973.
# Processing item 776.
# Processing item 2258.
# Processing item 12795.
# Processing item 8155.
# Processing item 14049.
# Processing item 10831.
# Processing item 5225.
# Processing item 16671.
# Processing item 1648.
# Processing item 15550.
# Processing item 1689.
# Processing item 12415.
# Processing item 15094.
# Processing item 3505.
# Processing item 14199.
# Processing item 8319.
# Processing item 6563.
# Processing item 12073.
# Processing item 14112.
# Processing item 763.
# Processing item 18314.
# Processing item 9837.
# Processing item 6814.
# Processing item 7975.
# Processing item 17148.
# Processing item 2344.
# Processing item 4648.
# Processing item 10982.
# Processing item 12793.
# Processing item 11175.
# Processing item 6270.
# Processing item 11785.
# Processing item 6326.
# Processing item 14138.
# Processing item 17081.
# Processing item 10429.
# Processing item 15890.
# Processing item 11373.
# Processing item 3355.
# Processing item 13126.
# Processing item 3247.
# Processing item 5345.
# Processing item 8096.
# Processing item 127.
# Processing item 3665.
# Processing item 13761.
# Processing item 19324.
# Processing item 6014.
# Processing item 4204.
# Processing item 3033.
# Processing item 3425.
# Processing item 19679.
# Processing item 12987.
# Processing item 8987.
# Processing item 10942.
# Processing item 6732.
# Processing item 12915.
# Processing item 16741.
# Processing item 10227.
# Processing item 14332.
# Processing item 53.
# Processing item 9581.
# Processing item 16110.
# Processing item 1753.
# Processing item 11062.
# Processing item 18692.
# Processing item 10586.
# Processing item 3759.
# Processing item 3683.
# Processing item 6848.
# Processing item 61.
# Processing item 4170.
# Processing item 19074.
# Processing item 19347.
# Processing item 274.
# Processing item 5722.
# Processing item 4468.
# Processing item 1779.
# Processing item 11590.
# Processing item 16020.
# Processing item 5044.
# Processing item 8740.
# Processing item 6345.
# Processing item 15403.
# Processing item 2443.
# Processing item 13934.
# Processing item 5176.
# Processing item 3321.
# Processing item 7653.
# Processing item 7316.
# Processing item 11185.
# Processing item 6883.
# Processing item 3966.
# Processing item 2823.
# Processing item 8568.
# Processing item 13973.
# Processing item 6284.
# Processing item 13770.
# Processing item 5155.
# Processing item 7779.
# Processing item 6285.
# Processing item 14629.
# Processing item 17519.
# Processing item 13438.
# Processing item 13379.
# Processing item 6120.
# Processing item 8122.
# Processing item 6156.
# Processing item 82.
# Processing item 17040.
# Processing item 18509.
# Processing item 17523.
# Processing item 318.
# Processing item 8858.
# Processing item 13170.
# Processing item 11890.
# Processing item 1990.
# Processing item 19175.
# Processing item 2204.
# Processing item 6142.
# Processing item 10517.
# Processing item 11687.
# Processing item 2796.
# Processing item 1243.
# Processing item 15958.
# Processing item 19369.
# Processing item 16501.
# Processing item 11418.
# Processing item 15929.
# Processing item 6505.
# Processing item 15242.
# Processing item 9297.
# Processing item 9153.
# Processing item 9609.
# Processing item 5032.
# Processing item 5308.
# Processing item 11202.
# Processing item 4289.
# Processing item 14414.
# Processing item 19504.
# Processing item 12849.
# Processing item 14280.
# Processing item 5522.
# Processing item 9746.
# Processing item 12053.
# Processing item 3160.
# Processing item 7247.
# Processing item 10112.
# Processing item 16158.
# Processing item 2870.
# Processing item 8748.
# Processing item 2271.
# Processing item 102.
# Processing item 5455.
# Processing item 12285.
# Processing item 16853.
# Processing item 9035.
# Processing item 3728.
# Processing item 13071.
# Processing item 8447.
# Processing item 16356.
# Processing item 10393.
# Processing item 9701.
# Processing item 14070.
# Processing item 6822.
# Processing item 14164.
# Processing item 17838.
# Processing item 10002.
# Processing item 14564.
# Processing item 11943.
# Processing item 14557.
# Processing item 19574.
# Processing item 6027.
# Processing item 13303.
# Processing item 10374.
# Processing item 15068.
# Processing item 8759.
# Processing item 11671.
# Processing item 10342.
# Processing item 13644.
# Processing item 16424.
# Processing item 12733.
# Processing item 17790.
# Processing item 1813.
# Processing item 1309.
# Processing item 8480.
# Processing item 19649.
# Processing item 17298.
# Processing item 11540.
# Processing item 534.
# Processing item 6917.
# Processing item 9813.
# Processing item 10104.
# Processing item 2555.
# Processing item 3590.
# Processing item 16398.
# Processing item 10619.
# Processing item 15083.
# Processing item 6246.
# Processing item 7508.
# Processing item 16453.
# Processing item 17787.
# Processing item 17371.
# Processing item 5885.
# Processing item 14502.
# Processing item 17439.
# Processing item 6994.
# Processing item 1934.
# Processing item 17943.
# Processing item 4708.
# Processing item 3528.
# Processing item 17635.
# Processing item 17391.
# Processing item 13913.
# Processing item 17424.
# Processing item 11512.
# Processing item 15603.
# Processing item 12318.
# Processing item 16541.
# Processing item 19338.
# Processing item 10998.
# Processing item 11416.
# Processing item 9892.
# Processing item 7649.
# Processing item 7115.
# Processing item 15363.
# Processing item 14187.
# Processing item 12397.
# Processing item 18488.
# Processing item 11889.
# Processing item 15373.
# Processing item 12565.
# Processing item 3890.
# Processing item 16296.
# Processing item 9631.
# Processing item 18043.
# Processing item 17902.
# Processing item 5717.
# Processing item 6015.
# Processing item 4986.
# Processing item 5864.
# Processing item 3292.
# Processing item 13933.
# Processing item 6391.
# Processing item 11918.
# Processing item 10513.
# Processing item 989.
# Processing item 17679.
# Processing item 15372.
# Processing item 17464.
# Processing item 4233.
# Processing item 2825.
# Processing item 13365.
# Processing item 17428.
# Processing item 1020.
# Processing item 12953.
# Processing item 16418.
# Processing item 12827.
# Processing item 2831.
# Processing item 4202.
# Processing item 18950.
# Processing item 15057.
# Processing item 1417.
# Processing item 13350.
# Processing item 11035.
# Processing item 7780.
# Processing item 18993.
# Processing item 19318.
# Processing item 16044.
# Processing item 7098.
# Processing item 10668.
# Processing item 3424.
# Processing item 12545.
# Processing item 19126.
# Processing item 7079.
# Processing item 8844.
# Processing item 5049.
# Processing item 10311.
# Processing item 12403.
# Processing item 4751.
# Processing item 12279.
# Processing item 17591.
# Processing item 13082.
# Processing item 14155.
# Processing item 3431.
# Processing item 4970.
# Processing item 1174.
# Processing item 1316.
# Processing item 18263.
# Processing item 17034.
# Processing item 13236.
# Processing item 18589.
# Processing item 3828.
# Processing item 7646.
# Processing item 7317.
# Processing item 13168.
# Processing item 1369.
# Processing item 18553.
# Processing item 11128.
# Processing item 16190.
# Processing item 7501.
# Processing item 14054.
# Processing item 7029.
# Processing item 7489.
# Processing item 832.
# Processing item 3478.
# Processing item 4605.
# Processing item 8671.
# Processing item 17151.
# Processing item 12777.
# Processing item 5317.
# Processing item 7553.
# Processing item 7176.
# Processing item 4357.
# Processing item 13515.
# Processing item 12517.
# Processing item 422.
# Processing item 8365.
# Processing item 5745.
# Processing item 12150.
# Processing item 7403.
# Processing item 16030.
# Processing item 8978.
# Processing item 11174.
# Processing item 7068.
# Processing item 11498.
# Processing item 3256.
# Processing item 18965.
# Processing item 9312.
# Processing item 10305.
# Processing item 4953.
# Processing item 11322.
# Processing item 19496.
# Processing item 1694.
# Processing item 13700.
# Processing item 9098.
# Processing item 1951.
# Processing item 7574.
# Processing item 16661.
# Processing item 14815.
# Processing item 283.
# Processing item 6429.
# Processing item 4979.
# Processing item 19064.
# Processing item 3132.
# Processing item 15858.
# Processing item 15236.
# Processing item 2793.
# Processing item 16611.
# Processing item 1758.
# Processing item 12310.
# Processing item 15347.
# Processing item 17223.
# Processing item 19676.
# Processing item 19297.
# Processing item 1718.
# Processing item 12722.
# Processing item 6678.
# Processing item 11680.
# Processing item 4176.
# Processing item 1644.
# Processing item 3489.
# Processing item 774.
# Processing item 3614.
# Processing item 3127.
# Processing item 9651.
# Processing item 4211.
# Processing item 16993.
# Processing item 14923.
# Processing item 13996.
# Processing item 11929.
# Processing item 13049.
# Processing item 11920.
# Processing item 4185.
# Processing item 2004.
# Processing item 1606.
# Processing item 16892.
# Processing item 7940.
# Processing item 17775.
# Processing item 19182.
# Processing item 2788.
# Processing item 7192.
# Processing item 15559.
# Processing item 17322.
# Processing item 9042.
# Processing item 9229.
# Processing item 1359.
# Processing item 8560.
# Processing item 2194.
# Processing item 13356.
# Processing item 5301.
# Processing item 6064.
# Processing item 11617.
# Processing item 18558.
# Processing item 5669.
# Processing item 6756.
# Processing item 18407.
# Processing item 12745.
# Processing item 1002.
# Processing item 7992.
# Processing item 6590.
# Processing item 16706.
# Processing item 3679.
# Processing item 18410.
# Processing item 12093.
# Processing item 5192.
# Processing item 10548.
# Processing item 5659.
# Processing item 18745.
# Processing item 6094.
# Processing item 19654.
# Processing item 7207.
# Processing item 9099.
# Processing item 12763.
# Processing item 9489.
# Processing item 15400.
# Processing item 11327.
# Processing item 1463.
# Processing item 2137.
# Processing item 64.
# Processing item 2646.
# Processing item 12210.
# Processing item 12205.
# Processing item 18598.
# Processing item 18228.
# Processing item 9183.
# Processing item 2099.
# Processing item 16764.
# Processing item 7373.
# Processing item 8687.
# Processing item 1662.
# Processing item 16920.
# Processing item 14380.
# Processing item 1612.
# Processing item 10281.
# Processing item 2806.
# Processing item 17998.
# Processing item 5001.
# Processing item 5939.
# Processing item 18097.
# Processing item 5307.
# Processing item 10008.
# Processing item 1974.
# Processing item 17218.
# Processing item 7559.
# Processing item 10836.
# Processing item 14458.
# Processing item 15319.
# Processing item 5260.
# Processing item 1660.
# Processing item 792.
# Processing item 3993.
# Processing item 1461.
# Processing item 15988.
# Processing item 11117.
# Processing item 2370.
# Processing item 11772.
# Processing item 3851.
# Processing item 6903.
# Processing item 12698.
# Processing item 7482.
# Processing item 17053.
# Processing item 19537.
# Processing item 156.
# Processing item 2969.
# Processing item 13265.
# Processing item 16616.
# Processing item 3821.
# Processing item 13182.
# Processing item 18781.
# Processing item 13209.
# Processing item 12294.
# Processing item 8371.
# Processing item 10736.
# Processing item 16061.
# Processing item 7581.
# Processing item 634.
# Processing item 1467.
# Processing item 2770.
# Processing item 11819.
# Processing item 14097.
# Processing item 15228.
# Processing item 4558.
# Processing item 461.
# Processing item 7782.
# Processing item 4051.
# Processing item 17796.
# Processing item 1904.
# Processing item 6839.
# Processing item 3560.
# Processing item 14101.
# Processing item 9987.
# Processing item 7654.
# Processing item 5489.
# Processing item 10204.
# Processing item 16104.
# Processing item 2385.
# Processing item 14204.
# Processing item 6900.
# Processing item 15106.
# Processing item 3361.
# Processing item 16151.
# Processing item 7497.
# Processing item 12341.
# Processing item 2371.
# Processing item 11924.
# Processing item 4870.
# Processing item 10136.
# Processing item 6915.
# Processing item 15500.
# Processing item 11993.
# Processing item 4578.
# Processing item 9163.
# Processing item 17001.
# Processing item 18743.
# Processing item 11188.
# Processing item 10532.
# Processing item 5401.
# Processing item 15965.
# Processing item 6198.
# Processing item 6238.
# Processing item 6745.
# Processing item 19281.
# Processing item 17778.
# Processing item 12952.
# Processing item 4412.
# Processing item 18935.
# Processing item 3021.
# Processing item 13342.
# Processing item 11378.
# Processing item 16464.
# Processing item 11178.
# Processing item 4456.
# Processing item 16535.
# Processing item 15070.
# Processing item 7436.
# Processing item 17225.
# Processing item 18450.
# Processing item 1560.
# Processing item 7037.
# Processing item 19217.
# Processing item 15182.
# Processing item 11852.
# Processing item 995.
# Processing item 9384.
# Processing item 13440.
# Processing item 1229.
# Processing item 17946.
# Processing item 11297.
# Processing item 2469.
# Processing item 16155.
# Processing item 5588.
# Processing item 5645.
# Processing item 15280.
# Processing item 7254.
# Processing item 19569.
# Processing item 16736.
# Processing item 8868.
# Processing item 18249.
# Processing item 14029.
# Processing item 5782.
# Processing item 5462.
# Processing item 1411.
# Processing item 15807.
# Processing item 3772.
# Processing item 18119.
# Processing item 15899.
# Processing item 5165.
# Processing item 18440.
# Processing item 14343.
# Processing item 8203.
# Processing item 15865.
# Processing item 4950.
# Processing item 12056.
# Processing item 504.
# Processing item 6659.
# Processing item 13353.
# Processing item 8660.
# Processing item 6251.
# Processing item 13523.
# Processing item 4538.
# Processing item 17063.
# Processing item 194.
# Processing item 7276.
# Processing item 11576.
# Processing item 13426.
# Processing item 7038.
# Processing item 4612.
# Processing item 13231.
# Processing item 10913.
# Processing item 17539.
# Processing item 464.
# Processing item 2569.
# Processing item 17843.
# Processing item 5740.
# Processing item 7548.
# Processing item 7455.
# Processing item 15317.
# Processing item 8109.
# Processing item 4262.
# Processing item 15779.
# Processing item 4924.
# Processing item 15266.
# Processing item 17374.
# Processing item 4865.
# Processing item 3313.
# Processing item 8518.
# Processing item 7981.
# Processing item 2546.
# Processing item 6112.
# Processing item 12961.
# Processing item 7695.
# Processing item 11464.
# Processing item 1481.
# Processing item 5224.
# Processing item 2717.
# Processing item 16711.
# Processing item 5572.
# Processing item 998.
# Processing item 10049.
# Processing item 8657.
# Processing item 9505.
# Processing item 7475.
# Processing item 13446.
# Processing item 1406.
# Processing item 13755.
# Processing item 9596.
# Processing item 5127.
# Processing item 13095.
# Processing item 7241.
# Processing item 9359.
# Processing item 9212.
# Processing item 15155.
# Processing item 5145.
# Processing item 9110.
# Processing item 13385.
# Processing item 13965.
# Image features extracted and saved!

# %%
features_array.shape
# Out:
# (19738, 768)

# %% [markdown]
# ## Video Encoder (Using the original video data)
# ## "num_frames": 16

# %%
import cv2
import numpy as np
import pandas as pd
import torch
import os
import gc  
from video_swin_transformer import SwinTransformer3D
from collections import OrderedDict

# %%
# Set device for PyTorch operations
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load and sort DataFrame
df = pd.read_csv('meta-simple.csv')
df.sort_values(by='itemID', inplace=True)

# Prepare directory for video features
features_dir = 'video_features'
os.makedirs(features_dir, exist_ok=True)

# List to store paths to feature files
temp_features_list = []

def load_and_preprocess_video(video_path, desired_num_frames=16):
    cap = cv2.VideoCapture(video_path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mean = np.array([123.675, 116.28, 103.53])
            std = np.array([58.395, 57.12, 57.375])
            frame = (frame - mean) / std
            frames.append(frame)
            if len(frames) == desired_num_frames:
                break
    finally:
        cap.release()
    
    target_size = (224, 224)
    resized_frames = [cv2.resize(frame, target_size) for frame in frames]
    batch = np.stack(resized_frames)
    batch = batch.transpose((0, 3, 1, 2))
    batch = np.expand_dims(batch, axis=0)
    return batch

# Initialize video feature extractor
extract_video = SwinTransformer3D(
    embed_dim=128,
    depths=[2, 2, 18, 2],
    num_heads=[4, 8, 16, 32],
    patch_size=(2, 4, 4),
    window_size=(8, 7, 7),
    drop_path_rate=0.0,
    patch_norm=True
)

# extract_video.load_state_dict(torch.load('./swin_base_patch244_window877_kinetics400_1k.pth'))
# extract_video = extract_video.to(device)

checkpoint = torch.load('./swin_base_patch244_window877_kinetics600_22k.pth')
new_state_dict = OrderedDict()
for k, v in checkpoint['state_dict'].items():
    # print(k)
    if 'backbone' in k:
        name = k[9:]
        new_state_dict[name] = v
extract_video.load_state_dict(new_state_dict)
extract_video = extract_video.to(device)


def extract_video_features(video_path, desired_num_frames):
    batch = load_and_preprocess_video(video_path, desired_num_frames)
    inputs = torch.tensor(batch).float().to(device)
    with torch.no_grad():
        features = extract_video(inputs.permute(0, 2, 1, 3, 4))
        features = torch.nn.functional.adaptive_avg_pool2d(features, (1, 1))
        features = features.squeeze(4).squeeze(3).permute(0, 2, 1)
    print(features.shape)
    return features.cpu().numpy()

videos_dir = '/root/autodl-tmp/simple/downloaded_videos'

# Process videos and extract features
for _, row in df.iterrows():
    item = row['item']
    video_path = os.path.join(videos_dir, f'{item}.mp4')
    temp_features_path = os.path.join(features_dir, f'temp_{item}.npy')
    print(f"Processing item {item}.")
    try:
        features = extract_video_features(video_path, desired_num_frames=16)
        np.save(temp_features_path, features.squeeze())
        temp_features_list.append(temp_features_path)
    except Exception as e:
        print(f"Error processing video {video_path}: {e}")
    gc.collect()
    if device.type == 'cuda':
        torch.cuda.empty_cache()

# Load and stack all features
all_features = []
for _, row in df.iterrows():
    item = row['item']
    temp_features_path = os.path.join(features_dir, f'temp_{item}.npy')
    features = np.load(temp_features_path)
    all_features.append(features)

all_features_array = np.stack(all_features)
np.save('oral_video_feat.npy', all_features_array)

print('All video features extracted and saved into a single file!')

# %%
all_features_array[:1]

# %%
all_features_array.shape

# %%
npy_file_path = 'oral_video_feat.npy'  # Change this to your file's path
npy_array = np.load(npy_file_path)

# Modify the array dimensions by averaging over the second dimension
npy_array_modified = npy_array.mean(axis=1)

# Optionally, save the modified array back to a file
modified_npy_file_path = 'video_feat.npy'  # Change this to your desired output file's path
np.save(modified_npy_file_path, npy_array_modified)

# If you want to check or use the modified array's shape
print(f"Modified array shape: {npy_array_modified.shape}")

# %% [markdown]
# ## Video Encoder(Using video slicing data)
# ## "num_frames": 5,

# %%
import torch
import numpy as np
import pandas as pd
import os
import cv2
import gc
from video_swin_transformer import SwinTransformer3D

from collections import OrderedDict

# %%
count = 0

# Set device for PyTorch operations
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load and sort DataFrame
df = pd.read_csv('meta_MicroLens.csv')
df.sort_values(by='itemID', inplace=True)

# Prepare directory for video features
features_dir = 'video_features'
os.makedirs(features_dir, exist_ok=True)

# List to store paths to feature files
temp_features_list = []

def load_and_preprocess_images(image_paths, target_size=(224, 224)):
    frames = []
    for path in image_paths:
        frame = cv2.imread(path)
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        mean = np.array([123.675, 116.28, 103.53])
        std = np.array([58.395, 57.12, 57.375])
        frame = (frame - mean) / std
        frame = cv2.resize(frame, target_size)
        frames.append(frame)
    batch = np.stack(frames)
    batch = batch.transpose((0, 3, 1, 2))
    batch = np.expand_dims(batch, axis=0)
    return batch

# Initialize video feature extractor (same as before)
extract_video = SwinTransformer3D(
    embed_dim=128,
    depths=[2, 2, 18, 2],
    num_heads=[4, 8, 16, 32],
    patch_size=(2, 4, 4),
    window_size=(8, 7, 7),
    drop_path_rate=0.0,
    patch_norm=True
)

# Load model checkpoint (same as before)
checkpoint = torch.load('./swin_base_patch244_window877_kinetics600_22k.pth')
new_state_dict = OrderedDict()
for k, v in checkpoint['state_dict'].items():
    if 'backbone' in k:
        name = k[9:]
        new_state_dict[name] = v
extract_video.load_state_dict(new_state_dict)
extract_video = extract_video.to(device)

def extract_features_from_images(image_folder, item, desired_num_frames=5):
    image_paths = [os.path.join(image_folder, f'{item}-{i}.jpg') for i in range(1, desired_num_frames+1)]
    batch = load_and_preprocess_images(image_paths)
    inputs = torch.tensor(batch).float().to(device)
    with torch.no_grad():
        features = extract_video(inputs.permute(0, 2, 1, 3, 4))
        features = torch.nn.functional.adaptive_avg_pool2d(features, (1, 1))
        features = features.squeeze(4).squeeze(3).permute(0, 2, 1)
    print(features.shape)
    return features.cpu().numpy()

images_dir = '/root/autodl-tmp/MicroLens-100k_frames_interval_1_number_5'

# Process images and extract features
for _, row in df.iterrows():
    count += 1
    item = row['item']
    temp_features_path = os.path.join(features_dir, f'temp_{item}.npy')
    print(f"Processing item {item}.")
    print(f"number {count}.")
    try:
        features = extract_features_from_images(images_dir, item, desired_num_frames=5)
        np.save(temp_features_path, features.squeeze())
        temp_features_list.append(temp_features_path)
    except Exception as e:
        print(f"Error processing images for item {item}: {e}")
    gc.collect()
    if device.type == 'cuda':
        torch.cuda.empty_cache()

# Load and stack all features (same as before)
all_features = []
for path in temp_features_list:
    features = np.load(path)
    all_features.append(features)

all_features_array = np.stack(all_features)
np.save('oral_video_feat.npy', all_features_array)

print('All features extracted and saved into a single file!')
# Out:
# Using device: cuda
# /root/miniconda3/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Processing item 9580.
# number 1.
# torch.Size([1, 3, 1024])
# Processing item 14631.
# number 2.
# torch.Size([1, 3, 1024])
# Processing item 7315.
# number 3.
# torch.Size([1, 3, 1024])
# Processing item 1955.
# number 4.
# torch.Size([1, 3, 1024])
# Processing item 9943.
# number 5.
# torch.Size([1, 3, 1024])
# Processing item 12077.
# number 6.
# torch.Size([1, 3, 1024])
# Processing item 8411.
# number 7.
# torch.Size([1, 3, 1024])
# Processing item 16821.
# number 8.
# torch.Size([1, 3, 1024])
# Processing item 13832.
# number 9.
# torch.Size([1, 3, 1024])
# Processing item 7771.
# number 10.
# torch.Size([1, 3, 1024])
# Processing item 9973.
# number 11.
# torch.Size([1, 3, 1024])
# Processing item 6763.
# number 12.
# torch.Size([1, 3, 1024])
# Processing item 2550.
# number 13.
# torch.Size([1, 3, 1024])
# Processing item 5266.
# number 14.
# torch.Size([1, 3, 1024])
# Processing item 8316.
# number 15.
# torch.Size([1, 3, 1024])
# Processing item 11733.
# number 16.
# torch.Size([1, 3, 1024])
# Processing item 16425.
# number 17.
# torch.Size([1, 3, 1024])
# Processing item 4253.
# number 18.
# torch.Size([1, 3, 1024])
# Processing item 1148.
# number 19.
# torch.Size([1, 3, 1024])
# Processing item 10589.
# number 20.
# torch.Size([1, 3, 1024])
# Processing item 621.
# number 21.
# torch.Size([1, 3, 1024])
# Processing item 11802.
# number 22.
# torch.Size([1, 3, 1024])
# Processing item 14283.
# number 23.
# torch.Size([1, 3, 1024])
# Processing item 18491.
# number 24.
# torch.Size([1, 3, 1024])
# Processing item 14394.
# number 25.
# torch.Size([1, 3, 1024])
# Processing item 5865.
# number 26.
# torch.Size([1, 3, 1024])
# Processing item 18490.
# number 27.
# torch.Size([1, 3, 1024])
# Processing item 3129.
# number 28.
# torch.Size([1, 3, 1024])
# Processing item 14044.
# number 29.
# torch.Size([1, 3, 1024])
# Processing item 11246.
# number 30.
# torch.Size([1, 3, 1024])
# Processing item 5535.
# number 31.
# torch.Size([1, 3, 1024])
# Processing item 18257.
# number 32.
# torch.Size([1, 3, 1024])
# Processing item 11698.
# number 33.
# torch.Size([1, 3, 1024])
# Processing item 15194.
# number 34.
# torch.Size([1, 3, 1024])
# Processing item 19120.
# number 35.
# torch.Size([1, 3, 1024])
# Processing item 9949.
# number 36.
# torch.Size([1, 3, 1024])
# Processing item 18584.
# number 37.
# torch.Size([1, 3, 1024])
# Processing item 12164.
# number 38.
# torch.Size([1, 3, 1024])
# Processing item 10509.
# number 39.
# torch.Size([1, 3, 1024])
# Processing item 14958.
# number 40.
# torch.Size([1, 3, 1024])
# Processing item 11527.
# number 41.
# torch.Size([1, 3, 1024])
# Processing item 12104.
# number 42.
# torch.Size([1, 3, 1024])
# Processing item 12109.
# number 43.
# torch.Size([1, 3, 1024])
# Processing item 1099.
# number 44.
# torch.Size([1, 3, 1024])
# Processing item 7454.
# number 45.
# torch.Size([1, 3, 1024])
# Processing item 5614.
# number 46.
# torch.Size([1, 3, 1024])
# Processing item 12735.
# number 47.
# torch.Size([1, 3, 1024])
# Processing item 4148.
# number 48.
# torch.Size([1, 3, 1024])
# Processing item 13539.
# number 49.
# torch.Size([1, 3, 1024])
# Processing item 4735.
# number 50.
# torch.Size([1, 3, 1024])
# Processing item 8019.
# number 51.
# torch.Size([1, 3, 1024])
# Processing item 2604.
# number 52.
# torch.Size([1, 3, 1024])
# Processing item 9590.
# number 53.
# torch.Size([1, 3, 1024])
# Processing item 4420.
# number 54.
# torch.Size([1, 3, 1024])
# Processing item 4502.
# number 55.
# torch.Size([1, 3, 1024])
# Processing item 5967.
# number 56.
# torch.Size([1, 3, 1024])
# Processing item 9919.
# number 57.
# torch.Size([1, 3, 1024])
# Processing item 1734.
# number 58.
# torch.Size([1, 3, 1024])
# Processing item 11685.
# number 59.
# torch.Size([1, 3, 1024])
# Processing item 4683.
# number 60.
# torch.Size([1, 3, 1024])
# Processing item 17944.
# number 61.
# torch.Size([1, 3, 1024])
# Processing item 19173.
# number 62.
# torch.Size([1, 3, 1024])
# Processing item 15173.
# number 63.
# torch.Size([1, 3, 1024])
# Processing item 2988.
# number 64.
# torch.Size([1, 3, 1024])
# Processing item 6097.
# number 65.
# torch.Size([1, 3, 1024])
# Processing item 11114.
# number 66.
# torch.Size([1, 3, 1024])
# Processing item 10635.
# number 67.
# torch.Size([1, 3, 1024])
# Processing item 19115.
# number 68.
# torch.Size([1, 3, 1024])
# Processing item 13748.
# number 69.
# torch.Size([1, 3, 1024])
# Processing item 3451.
# number 70.
# torch.Size([1, 3, 1024])
# Processing item 17543.
# number 71.
# torch.Size([1, 3, 1024])
# Processing item 16117.
# number 72.
# torch.Size([1, 3, 1024])
# Processing item 17803.
# number 73.
# torch.Size([1, 3, 1024])
# Processing item 414.
# number 74.
# torch.Size([1, 3, 1024])
# Processing item 7285.
# number 75.
# torch.Size([1, 3, 1024])
# Processing item 19482.
# number 76.
# torch.Size([1, 3, 1024])
# Processing item 17652.
# number 77.
# torch.Size([1, 3, 1024])
# Processing item 15876.
# number 78.
# torch.Size([1, 3, 1024])
# Processing item 6957.
# number 79.
# torch.Size([1, 3, 1024])
# Processing item 7362.
# number 80.
# torch.Size([1, 3, 1024])
# Processing item 18054.
# number 81.
# torch.Size([1, 3, 1024])
# Processing item 7060.
# number 82.
# torch.Size([1, 3, 1024])
# Processing item 9365.
# number 83.
# torch.Size([1, 3, 1024])
# Processing item 16467.
# number 84.
# torch.Size([1, 3, 1024])
# Processing item 858.
# number 85.
# torch.Size([1, 3, 1024])
# Processing item 2481.
# number 86.
# torch.Size([1, 3, 1024])
# Processing item 10941.
# number 87.
# torch.Size([1, 3, 1024])
# Processing item 8107.
# number 88.
# torch.Size([1, 3, 1024])
# Processing item 2900.
# number 89.
# torch.Size([1, 3, 1024])
# Processing item 10910.
# number 90.
# torch.Size([1, 3, 1024])
# Processing item 10514.
# number 91.
# torch.Size([1, 3, 1024])
# Processing item 4073.
# number 92.
# torch.Size([1, 3, 1024])
# Processing item 18750.
# number 93.
# torch.Size([1, 3, 1024])
# Processing item 1105.
# number 94.
# torch.Size([1, 3, 1024])
# Processing item 17400.
# number 95.
# torch.Size([1, 3, 1024])
# Processing item 17571.
# number 96.
# torch.Size([1, 3, 1024])
# Processing item 1704.
# number 97.
# torch.Size([1, 3, 1024])
# Processing item 7915.
# number 98.
# torch.Size([1, 3, 1024])
# Processing item 14450.
# number 99.
# torch.Size([1, 3, 1024])
# Processing item 7637.
# number 100.
# torch.Size([1, 3, 1024])
# Processing item 17552.
# number 101.
# torch.Size([1, 3, 1024])
# Processing item 14242.
# number 102.
# torch.Size([1, 3, 1024])
# Processing item 13834.
# number 103.
# torch.Size([1, 3, 1024])
# Processing item 15536.
# number 104.
# torch.Size([1, 3, 1024])
# Processing item 6989.
# number 105.
# torch.Size([1, 3, 1024])
# Processing item 10247.
# number 106.
# torch.Size([1, 3, 1024])
# Processing item 9819.
# number 107.
# torch.Size([1, 3, 1024])
# Processing item 14916.
# number 108.
# torch.Size([1, 3, 1024])
# Processing item 19078.
# number 109.
# torch.Size([1, 3, 1024])
# Processing item 15866.
# number 110.
# torch.Size([1, 3, 1024])
# Processing item 5305.
# number 111.
# torch.Size([1, 3, 1024])
# Processing item 10335.
# number 112.
# torch.Size([1, 3, 1024])
# Processing item 17655.
# number 113.
# torch.Size([1, 3, 1024])
# Processing item 11797.
# number 114.
# torch.Size([1, 3, 1024])
# Processing item 12792.
# number 115.
# torch.Size([1, 3, 1024])
# Processing item 18887.
# number 116.
# torch.Size([1, 3, 1024])
# Processing item 4295.
# number 117.
# torch.Size([1, 3, 1024])
# Processing item 8385.
# number 118.
# torch.Size([1, 3, 1024])
# Processing item 13775.
# number 119.
# torch.Size([1, 3, 1024])
# Processing item 18504.
# number 120.
# torch.Size([1, 3, 1024])
# Processing item 11204.
# number 121.
# torch.Size([1, 3, 1024])
# Processing item 1552.
# number 122.
# torch.Size([1, 3, 1024])
# Processing item 10741.
# number 123.
# torch.Size([1, 3, 1024])
# Processing item 13362.
# number 124.
# torch.Size([1, 3, 1024])
# Processing item 6718.
# number 125.
# torch.Size([1, 3, 1024])
# Processing item 17906.
# number 126.
# torch.Size([1, 3, 1024])
# Processing item 12198.
# number 127.
# torch.Size([1, 3, 1024])
# Processing item 6796.
# number 128.
# torch.Size([1, 3, 1024])
# Processing item 19117.
# number 129.
# torch.Size([1, 3, 1024])
# Processing item 8315.
# number 130.
# torch.Size([1, 3, 1024])
# Processing item 15411.
# number 131.
# torch.Size([1, 3, 1024])
# Processing item 1271.
# number 132.
# torch.Size([1, 3, 1024])
# Processing item 1547.
# number 133.
# torch.Size([1, 3, 1024])
# Processing item 11215.
# number 134.
# torch.Size([1, 3, 1024])
# Processing item 3166.
# number 135.
# torch.Size([1, 3, 1024])
# Processing item 14572.
# number 136.
# torch.Size([1, 3, 1024])
# Processing item 12732.
# number 137.
# torch.Size([1, 3, 1024])
# Processing item 16419.
# number 138.
# torch.Size([1, 3, 1024])
# Processing item 1050.
# number 139.
# torch.Size([1, 3, 1024])
# Processing item 606.
# number 140.
# torch.Size([1, 3, 1024])
# Processing item 7998.
# number 141.
# torch.Size([1, 3, 1024])
# Processing item 3619.
# number 142.
# torch.Size([1, 3, 1024])
# Processing item 3386.
# number 143.
# torch.Size([1, 3, 1024])
# Processing item 19029.
# number 144.
# torch.Size([1, 3, 1024])
# Processing item 1457.
# number 145.
# torch.Size([1, 3, 1024])
# Processing item 10539.
# number 146.
# torch.Size([1, 3, 1024])
# Processing item 272.
# number 147.
# torch.Size([1, 3, 1024])
# Processing item 15096.
# number 148.
# torch.Size([1, 3, 1024])
# Processing item 8528.
# number 149.
# torch.Size([1, 3, 1024])
# Processing item 16292.
# number 150.
# torch.Size([1, 3, 1024])
# Processing item 4387.
# number 151.
# torch.Size([1, 3, 1024])
# Processing item 3773.
# number 152.
# torch.Size([1, 3, 1024])
# Processing item 17556.
# number 153.
# torch.Size([1, 3, 1024])
# Processing item 10909.
# number 154.
# torch.Size([1, 3, 1024])
# Processing item 5537.
# number 155.
# torch.Size([1, 3, 1024])
# Processing item 10790.
# number 156.
# torch.Size([1, 3, 1024])
# Processing item 10382.
# number 157.
# torch.Size([1, 3, 1024])
# Processing item 8752.
# number 158.
# torch.Size([1, 3, 1024])
# Processing item 1661.
# number 159.
# torch.Size([1, 3, 1024])
# Processing item 8696.
# number 160.
# torch.Size([1, 3, 1024])
# Processing item 15148.
# number 161.
# torch.Size([1, 3, 1024])
# Processing item 17891.
# number 162.
# torch.Size([1, 3, 1024])
# Processing item 12741.
# number 163.
# torch.Size([1, 3, 1024])
# Processing item 9642.
# number 164.
# torch.Size([1, 3, 1024])
# Processing item 4298.
# number 165.
# torch.Size([1, 3, 1024])
# Processing item 1907.
# number 166.
# torch.Size([1, 3, 1024])
# Processing item 19325.
# number 167.
# torch.Size([1, 3, 1024])
# Processing item 19277.
# number 168.
# torch.Size([1, 3, 1024])
# Processing item 17745.
# number 169.
# torch.Size([1, 3, 1024])
# Processing item 10687.
# number 170.
# torch.Size([1, 3, 1024])
# Processing item 5710.
# number 171.
# torch.Size([1, 3, 1024])
# Processing item 15908.
# number 172.
# torch.Size([1, 3, 1024])
# Processing item 8268.
# number 173.
# torch.Size([1, 3, 1024])
# Processing item 12136.
# number 174.
# torch.Size([1, 3, 1024])
# Processing item 13404.
# number 175.
# torch.Size([1, 3, 1024])
# Processing item 4046.
# number 176.
# torch.Size([1, 3, 1024])
# Processing item 14078.
# number 177.
# torch.Size([1, 3, 1024])
# Processing item 13972.
# number 178.
# torch.Size([1, 3, 1024])
# Processing item 5655.
# number 179.
# torch.Size([1, 3, 1024])
# Processing item 17181.
# number 180.
# torch.Size([1, 3, 1024])
# Processing item 1330.
# number 181.
# torch.Size([1, 3, 1024])
# Processing item 5166.
# number 182.
# torch.Size([1, 3, 1024])
# Processing item 14993.
# number 183.
# torch.Size([1, 3, 1024])
# Processing item 8976.
# number 184.
# torch.Size([1, 3, 1024])
# Processing item 17045.
# number 185.
# torch.Size([1, 3, 1024])
# Processing item 17044.
# number 186.
# torch.Size([1, 3, 1024])
# Processing item 2405.
# number 187.
# torch.Size([1, 3, 1024])
# Processing item 1543.
# number 188.
# torch.Size([1, 3, 1024])
# Processing item 917.
# number 189.
# torch.Size([1, 3, 1024])
# Processing item 14043.
# number 190.
# torch.Size([1, 3, 1024])
# Processing item 17207.
# number 191.
# torch.Size([1, 3, 1024])
# Processing item 14469.
# number 192.
# torch.Size([1, 3, 1024])
# Processing item 17101.
# number 193.
# torch.Size([1, 3, 1024])
# Processing item 862.
# number 194.
# torch.Size([1, 3, 1024])
# Processing item 16182.
# number 195.
# torch.Size([1, 3, 1024])
# Processing item 10649.
# number 196.
# torch.Size([1, 3, 1024])
# Processing item 9317.
# number 197.
# torch.Size([1, 3, 1024])
# Processing item 2544.
# number 198.
# torch.Size([1, 3, 1024])
# Processing item 6525.
# number 199.
# torch.Size([1, 3, 1024])
# Processing item 14329.
# number 200.
# torch.Size([1, 3, 1024])
# Processing item 6714.
# number 201.
# torch.Size([1, 3, 1024])
# Processing item 5014.
# number 202.
# torch.Size([1, 3, 1024])
# Processing item 15766.
# number 203.
# torch.Size([1, 3, 1024])
# Processing item 17214.
# number 204.
# torch.Size([1, 3, 1024])
# Processing item 735.
# number 205.
# torch.Size([1, 3, 1024])
# Processing item 2181.
# number 206.
# torch.Size([1, 3, 1024])
# Processing item 16360.
# number 207.
# torch.Size([1, 3, 1024])
# Processing item 13921.
# number 208.
# torch.Size([1, 3, 1024])
# Processing item 13804.
# number 209.
# torch.Size([1, 3, 1024])
# Processing item 390.
# number 210.
# torch.Size([1, 3, 1024])
# Processing item 12983.
# number 211.
# torch.Size([1, 3, 1024])
# Processing item 8672.
# number 212.
# torch.Size([1, 3, 1024])
# Processing item 14361.
# number 213.
# torch.Size([1, 3, 1024])
# Processing item 2709.
# number 214.
# torch.Size([1, 3, 1024])
# Processing item 1195.
# number 215.
# torch.Size([1, 3, 1024])
# Processing item 2484.
# number 216.
# torch.Size([1, 3, 1024])
# Processing item 11972.
# number 217.
# torch.Size([1, 3, 1024])
# Processing item 15838.
# number 218.
# torch.Size([1, 3, 1024])
# Processing item 17593.
# number 219.
# torch.Size([1, 3, 1024])
# Processing item 1681.
# number 220.
# torch.Size([1, 3, 1024])
# Processing item 9072.
# number 221.
# torch.Size([1, 3, 1024])
# Processing item 726.
# number 222.
# torch.Size([1, 3, 1024])
# Processing item 5417.
# number 223.
# torch.Size([1, 3, 1024])
# Processing item 15926.
# number 224.
# torch.Size([1, 3, 1024])
# Processing item 19309.
# number 225.
# torch.Size([1, 3, 1024])
# Processing item 1240.
# number 226.
# torch.Size([1, 3, 1024])
# Processing item 1586.
# number 227.
# torch.Size([1, 3, 1024])
# Processing item 13378.
# number 228.
# torch.Size([1, 3, 1024])
# Processing item 17419.
# number 229.
# torch.Size([1, 3, 1024])
# Processing item 14874.
# number 230.
# torch.Size([1, 3, 1024])
# Processing item 2387.
# number 231.
# torch.Size([1, 3, 1024])
# Processing item 14030.
# number 232.
# torch.Size([1, 3, 1024])
# Processing item 10328.
# number 233.
# torch.Size([1, 3, 1024])
# Processing item 6784.
# number 234.
# torch.Size([1, 3, 1024])
# Processing item 5133.
# number 235.
# torch.Size([1, 3, 1024])
# Processing item 15570.
# number 236.
# torch.Size([1, 3, 1024])
# Processing item 14003.
# number 237.
# torch.Size([1, 3, 1024])
# Processing item 14678.
# number 238.
# torch.Size([1, 3, 1024])
# Processing item 5648.
# number 239.
# torch.Size([1, 3, 1024])
# Processing item 12522.
# number 240.
# torch.Size([1, 3, 1024])
# Processing item 15968.
# number 241.
# torch.Size([1, 3, 1024])
# Processing item 19530.
# number 242.
# torch.Size([1, 3, 1024])
# Processing item 4266.
# number 243.
# torch.Size([1, 3, 1024])
# Processing item 11443.
# number 244.
# torch.Size([1, 3, 1024])
# Processing item 6243.
# number 245.
# torch.Size([1, 3, 1024])
# Processing item 929.
# number 246.
# torch.Size([1, 3, 1024])
# Processing item 6353.
# number 247.
# torch.Size([1, 3, 1024])
# Processing item 9750.
# number 248.
# torch.Size([1, 3, 1024])
# Processing item 18758.
# number 249.
# torch.Size([1, 3, 1024])
# Processing item 15521.
# number 250.
# torch.Size([1, 3, 1024])
# Processing item 11126.
# number 251.
# torch.Size([1, 3, 1024])
# Processing item 7655.
# number 252.
# torch.Size([1, 3, 1024])
# Processing item 12505.
# number 253.
# torch.Size([1, 3, 1024])
# Processing item 8071.
# number 254.
# torch.Size([1, 3, 1024])
# Processing item 3716.
# number 255.
# torch.Size([1, 3, 1024])
# Processing item 3065.
# number 256.
# torch.Size([1, 3, 1024])
# Processing item 13046.
# number 257.
# torch.Size([1, 3, 1024])
# Processing item 15983.
# number 258.
# torch.Size([1, 3, 1024])
# Processing item 4542.
# number 259.
# torch.Size([1, 3, 1024])
# Processing item 17565.
# number 260.
# torch.Size([1, 3, 1024])
# Processing item 14427.
# number 261.
# torch.Size([1, 3, 1024])
# Processing item 18376.
# number 262.
# torch.Size([1, 3, 1024])
# Processing item 5429.
# number 263.
# torch.Size([1, 3, 1024])
# Processing item 1593.
# number 264.
# torch.Size([1, 3, 1024])
# Processing item 19615.
# number 265.
# torch.Size([1, 3, 1024])
# Processing item 11468.
# number 266.
# torch.Size([1, 3, 1024])
# Processing item 7326.
# number 267.
# torch.Size([1, 3, 1024])
# Processing item 8910.
# number 268.
# torch.Size([1, 3, 1024])
# Processing item 4962.
# number 269.
# torch.Size([1, 3, 1024])
# Processing item 13164.
# number 270.
# torch.Size([1, 3, 1024])
# Processing item 15118.
# number 271.
# torch.Size([1, 3, 1024])
# Processing item 10929.
# number 272.
# torch.Size([1, 3, 1024])
# Processing item 2837.
# number 273.
# torch.Size([1, 3, 1024])
# Processing item 628.
# number 274.
# torch.Size([1, 3, 1024])
# Processing item 8260.
# number 275.
# torch.Size([1, 3, 1024])
# Processing item 17930.
# number 276.
# torch.Size([1, 3, 1024])
# Processing item 4448.
# number 277.
# torch.Size([1, 3, 1024])
# Processing item 6375.
# number 278.
# torch.Size([1, 3, 1024])
# Processing item 12421.
# number 279.
# torch.Size([1, 3, 1024])
# Processing item 13898.
# number 280.
# torch.Size([1, 3, 1024])
# Processing item 19420.
# number 281.
# torch.Size([1, 3, 1024])
# Processing item 4419.
# number 282.
# torch.Size([1, 3, 1024])
# Processing item 14040.
# number 283.
# torch.Size([1, 3, 1024])
# Processing item 12376.
# number 284.
# torch.Size([1, 3, 1024])
# Processing item 10360.
# number 285.
# torch.Size([1, 3, 1024])
# Processing item 3441.
# number 286.
# torch.Size([1, 3, 1024])
# Processing item 689.
# number 287.
# torch.Size([1, 3, 1024])
# Processing item 2548.
# number 288.
# torch.Size([1, 3, 1024])
# Processing item 7796.
# number 289.
# torch.Size([1, 3, 1024])
# Processing item 16412.
# number 290.
# torch.Size([1, 3, 1024])
# Processing item 14812.
# number 291.
# torch.Size([1, 3, 1024])
# Processing item 17123.
# number 292.
# torch.Size([1, 3, 1024])
# Processing item 10777.
# number 293.
# torch.Size([1, 3, 1024])
# Processing item 4212.
# number 294.
# torch.Size([1, 3, 1024])
# Processing item 7795.
# number 295.
# torch.Size([1, 3, 1024])
# Processing item 12131.
# number 296.
# torch.Size([1, 3, 1024])
# Processing item 480.
# number 297.
# torch.Size([1, 3, 1024])
# Processing item 5375.
# number 298.
# torch.Size([1, 3, 1024])
# Processing item 15547.
# number 299.
# torch.Size([1, 3, 1024])
# Processing item 15135.
# number 300.
# torch.Size([1, 3, 1024])
# Processing item 18844.
# number 301.
# torch.Size([1, 3, 1024])
# Processing item 5438.
# number 302.
# torch.Size([1, 3, 1024])
# Processing item 7894.
# number 303.
# torch.Size([1, 3, 1024])
# Processing item 15606.
# number 304.
# torch.Size([1, 3, 1024])
# Processing item 17845.
# number 305.
# torch.Size([1, 3, 1024])
# Processing item 10504.
# number 306.
# torch.Size([1, 3, 1024])
# Processing item 9345.
# number 307.
# torch.Size([1, 3, 1024])
# Processing item 7736.
# number 308.
# torch.Size([1, 3, 1024])
# Processing item 5229.
# number 309.
# torch.Size([1, 3, 1024])
# Processing item 1789.
# number 310.
# torch.Size([1, 3, 1024])
# Processing item 16381.
# number 311.
# torch.Size([1, 3, 1024])
# Processing item 755.
# number 312.
# torch.Size([1, 3, 1024])
# Processing item 2609.
# number 313.
# torch.Size([1, 3, 1024])
# Processing item 2881.
# number 314.
# torch.Size([1, 3, 1024])
# Processing item 12312.
# number 315.
# torch.Size([1, 3, 1024])
# Processing item 16883.
# number 316.
# torch.Size([1, 3, 1024])
# Processing item 2432.
# number 317.
# torch.Size([1, 3, 1024])
# Processing item 17273.
# number 318.
# torch.Size([1, 3, 1024])
# Processing item 3346.
# number 319.
# torch.Size([1, 3, 1024])
# Processing item 1795.
# number 320.
# torch.Size([1, 3, 1024])
# Processing item 2475.
# number 321.
# torch.Size([1, 3, 1024])
# Processing item 14693.
# number 322.
# torch.Size([1, 3, 1024])
# Processing item 5302.
# number 323.
# torch.Size([1, 3, 1024])
# Processing item 8851.
# number 324.
# torch.Size([1, 3, 1024])
# Processing item 12579.
# number 325.
# torch.Size([1, 3, 1024])
# Processing item 5433.
# number 326.
# torch.Size([1, 3, 1024])
# Processing item 681.
# number 327.
# torch.Size([1, 3, 1024])
# Processing item 18437.
# number 328.
# torch.Size([1, 3, 1024])
# Processing item 3509.
# number 329.
# torch.Size([1, 3, 1024])
# Processing item 10413.
# number 330.
# torch.Size([1, 3, 1024])
# Processing item 10774.
# number 331.
# torch.Size([1, 3, 1024])
# Processing item 18107.
# number 332.
# torch.Size([1, 3, 1024])
# Processing item 10260.
# number 333.
# torch.Size([1, 3, 1024])
# Processing item 1388.
# number 334.
# torch.Size([1, 3, 1024])
# Processing item 18267.
# number 335.
# torch.Size([1, 3, 1024])
# Processing item 7689.
# number 336.
# torch.Size([1, 3, 1024])
# Processing item 5683.
# number 337.
# torch.Size([1, 3, 1024])
# Processing item 17856.
# number 338.
# torch.Size([1, 3, 1024])
# Processing item 15690.
# number 339.
# torch.Size([1, 3, 1024])
# Processing item 3311.
# number 340.
# torch.Size([1, 3, 1024])
# Processing item 4276.
# number 341.
# torch.Size([1, 3, 1024])
# Processing item 6527.
# number 342.
# torch.Size([1, 3, 1024])
# Processing item 14211.
# number 343.
# torch.Size([1, 3, 1024])
# Processing item 4400.
# number 344.
# torch.Size([1, 3, 1024])
# Processing item 5792.
# number 345.
# torch.Size([1, 3, 1024])
# Processing item 1631.
# number 346.
# torch.Size([1, 3, 1024])
# Processing item 8482.
# number 347.
# torch.Size([1, 3, 1024])
# Processing item 14664.
# number 348.
# torch.Size([1, 3, 1024])
# Processing item 7447.
# number 349.
# torch.Size([1, 3, 1024])
# Processing item 13113.
# number 350.
# torch.Size([1, 3, 1024])
# Processing item 16873.
# number 351.
# torch.Size([1, 3, 1024])
# Processing item 14913.
# number 352.
# torch.Size([1, 3, 1024])
# Processing item 7354.
# number 353.
# torch.Size([1, 3, 1024])
# Processing item 949.
# number 354.
# torch.Size([1, 3, 1024])
# Processing item 9767.
# number 355.
# torch.Size([1, 3, 1024])
# Processing item 2720.
# number 356.
# torch.Size([1, 3, 1024])
# Processing item 15152.
# number 357.
# torch.Size([1, 3, 1024])
# Processing item 5767.
# number 358.
# torch.Size([1, 3, 1024])
# Processing item 17599.
# number 359.
# torch.Size([1, 3, 1024])
# Processing item 18120.
# number 360.
# torch.Size([1, 3, 1024])
# Processing item 18356.
# number 361.
# torch.Size([1, 3, 1024])
# Processing item 17589.
# number 362.
# torch.Size([1, 3, 1024])
# Processing item 16916.
# number 363.
# torch.Size([1, 3, 1024])
# Processing item 4598.
# number 364.
# torch.Size([1, 3, 1024])
# Processing item 11069.
# number 365.
# torch.Size([1, 3, 1024])
# Processing item 10474.
# number 366.
# torch.Size([1, 3, 1024])
# Processing item 9432.
# number 367.
# torch.Size([1, 3, 1024])
# Processing item 17264.
# number 368.
# torch.Size([1, 3, 1024])
# Processing item 17596.
# number 369.
# torch.Size([1, 3, 1024])
# Processing item 18299.
# number 370.
# torch.Size([1, 3, 1024])
# Processing item 7777.
# number 371.
# torch.Size([1, 3, 1024])
# Processing item 14687.
# number 372.
# torch.Size([1, 3, 1024])
# Processing item 8824.
# number 373.
# torch.Size([1, 3, 1024])
# Processing item 10742.
# number 374.
# torch.Size([1, 3, 1024])
# Processing item 3104.
# number 375.
# torch.Size([1, 3, 1024])
# Processing item 18508.
# number 376.
# torch.Size([1, 3, 1024])
# Processing item 11842.
# number 377.
# torch.Size([1, 3, 1024])
# Processing item 29.
# number 378.
# torch.Size([1, 3, 1024])
# Processing item 17482.
# number 379.
# torch.Size([1, 3, 1024])
# Processing item 11087.
# number 380.
# torch.Size([1, 3, 1024])
# Processing item 8449.
# number 381.
# torch.Size([1, 3, 1024])
# Processing item 8161.
# number 382.
# torch.Size([1, 3, 1024])
# Processing item 5344.
# number 383.
# torch.Size([1, 3, 1024])
# Processing item 5546.
# number 384.
# torch.Size([1, 3, 1024])
# Processing item 4306.
# number 385.
# torch.Size([1, 3, 1024])
# Processing item 13754.
# number 386.
# torch.Size([1, 3, 1024])
# Processing item 1038.
# number 387.
# torch.Size([1, 3, 1024])
# Processing item 8723.
# number 388.
# torch.Size([1, 3, 1024])
# Processing item 11782.
# number 389.
# torch.Size([1, 3, 1024])
# Processing item 14452.
# number 390.
# torch.Size([1, 3, 1024])
# Processing item 15428.
# number 391.
# torch.Size([1, 3, 1024])
# Processing item 3529.
# number 392.
# torch.Size([1, 3, 1024])
# Processing item 7137.
# number 393.
# torch.Size([1, 3, 1024])
# Processing item 11093.
# number 394.
# torch.Size([1, 3, 1024])
# Processing item 5262.
# number 395.
# torch.Size([1, 3, 1024])
# Processing item 9202.
# number 396.
# torch.Size([1, 3, 1024])
# Processing item 7279.
# number 397.
# torch.Size([1, 3, 1024])
# Processing item 6161.
# number 398.
# torch.Size([1, 3, 1024])
# Processing item 3591.
# number 399.
# torch.Size([1, 3, 1024])
# Processing item 11098.
# number 400.
# torch.Size([1, 3, 1024])
# Processing item 12510.
# number 401.
# torch.Size([1, 3, 1024])
# Processing item 16642.
# number 402.
# torch.Size([1, 3, 1024])
# Processing item 4058.
# number 403.
# torch.Size([1, 3, 1024])
# Processing item 5790.
# number 404.
# torch.Size([1, 3, 1024])
# Processing item 18297.
# number 405.
# torch.Size([1, 3, 1024])
# Processing item 13043.
# number 406.
# torch.Size([1, 3, 1024])
# Processing item 1768.
# number 407.
# torch.Size([1, 3, 1024])
# Processing item 14943.
# number 408.
# torch.Size([1, 3, 1024])
# Processing item 18791.
# number 409.
# torch.Size([1, 3, 1024])
# Processing item 13425.
# number 410.
# torch.Size([1, 3, 1024])
# Processing item 9389.
# number 411.
# torch.Size([1, 3, 1024])
# Processing item 4496.
# number 412.
# torch.Size([1, 3, 1024])
# Processing item 14150.
# number 413.
# torch.Size([1, 3, 1024])
# Processing item 9096.
# number 414.
# torch.Size([1, 3, 1024])
# Processing item 1971.
# number 415.
# torch.Size([1, 3, 1024])
# Processing item 19361.
# number 416.
# torch.Size([1, 3, 1024])
# Processing item 12375.
# number 417.
# torch.Size([1, 3, 1024])
# Processing item 11222.
# number 418.
# torch.Size([1, 3, 1024])
# Processing item 11961.
# number 419.
# torch.Size([1, 3, 1024])
# Processing item 9722.
# number 420.
# torch.Size([1, 3, 1024])
# Processing item 8993.
# number 421.
# torch.Size([1, 3, 1024])
# Processing item 8173.
# number 422.
# torch.Size([1, 3, 1024])
# Processing item 17646.
# number 423.
# torch.Size([1, 3, 1024])
# Processing item 9843.
# number 424.
# torch.Size([1, 3, 1024])
# Processing item 14447.
# number 425.
# torch.Size([1, 3, 1024])
# Processing item 6291.
# number 426.
# torch.Size([1, 3, 1024])
# Processing item 3872.
# number 427.
# torch.Size([1, 3, 1024])
# Processing item 8714.
# number 428.
# torch.Size([1, 3, 1024])
# Processing item 13472.
# number 429.
# torch.Size([1, 3, 1024])
# Processing item 8623.
# number 430.
# torch.Size([1, 3, 1024])
# Processing item 95.
# number 431.
# torch.Size([1, 3, 1024])
# Processing item 14860.
# number 432.
# torch.Size([1, 3, 1024])
# Processing item 18862.
# number 433.
# torch.Size([1, 3, 1024])
# Processing item 874.
# number 434.
# torch.Size([1, 3, 1024])
# Processing item 13047.
# number 435.
# torch.Size([1, 3, 1024])
# Processing item 5396.
# number 436.
# torch.Size([1, 3, 1024])
# Processing item 9243.
# number 437.
# torch.Size([1, 3, 1024])
# Processing item 1324.
# number 438.
# torch.Size([1, 3, 1024])
# Processing item 12556.
# number 439.
# torch.Size([1, 3, 1024])
# Processing item 8825.
# number 440.
# torch.Size([1, 3, 1024])
# Processing item 441.
# number 441.
# torch.Size([1, 3, 1024])
# Processing item 15591.
# number 442.
# torch.Size([1, 3, 1024])
# Processing item 18720.
# number 443.
# torch.Size([1, 3, 1024])
# Processing item 16142.
# number 444.
# torch.Size([1, 3, 1024])
# Processing item 16988.
# number 445.
# torch.Size([1, 3, 1024])
# Processing item 16224.
# number 446.
# torch.Size([1, 3, 1024])
# Processing item 5436.
# number 447.
# torch.Size([1, 3, 1024])
# Processing item 6371.
# number 448.
# torch.Size([1, 3, 1024])
# Processing item 1851.
# number 449.
# torch.Size([1, 3, 1024])
# Processing item 15424.
# number 450.
# torch.Size([1, 3, 1024])
# Processing item 9629.
# number 451.
# torch.Size([1, 3, 1024])
# Processing item 7468.
# number 452.
# torch.Size([1, 3, 1024])
# Processing item 19308.
# number 453.
# torch.Size([1, 3, 1024])
# Processing item 16348.
# number 454.
# torch.Size([1, 3, 1024])
# Processing item 8611.
# number 455.
# torch.Size([1, 3, 1024])
# Processing item 4376.
# number 456.
# torch.Size([1, 3, 1024])
# Processing item 2286.
# number 457.
# torch.Size([1, 3, 1024])
# Processing item 8309.
# number 458.
# torch.Size([1, 3, 1024])
# Processing item 14231.
# number 459.
# torch.Size([1, 3, 1024])
# Processing item 12548.
# number 460.
# torch.Size([1, 3, 1024])
# Processing item 608.
# number 461.
# torch.Size([1, 3, 1024])
# Processing item 18422.
# number 462.
# torch.Size([1, 3, 1024])
# Processing item 5019.
# number 463.
# torch.Size([1, 3, 1024])
# Processing item 18806.
# number 464.
# torch.Size([1, 3, 1024])
# Processing item 936.
# number 465.
# torch.Size([1, 3, 1024])
# Processing item 9510.
# number 466.
# torch.Size([1, 3, 1024])
# Processing item 16626.
# number 467.
# torch.Size([1, 3, 1024])
# Processing item 4635.
# number 468.
# torch.Size([1, 3, 1024])
# Processing item 12496.
# number 469.
# torch.Size([1, 3, 1024])
# Processing item 6948.
# number 470.
# torch.Size([1, 3, 1024])
# Processing item 10111.
# number 471.
# torch.Size([1, 3, 1024])
# Processing item 17604.
# number 472.
# torch.Size([1, 3, 1024])
# Processing item 9308.
# number 473.
# torch.Size([1, 3, 1024])
# Processing item 3797.
# number 474.
# torch.Size([1, 3, 1024])
# Processing item 17978.
# number 475.
# torch.Size([1, 3, 1024])
# Processing item 5668.
# number 476.
# torch.Size([1, 3, 1024])
# Processing item 16068.
# number 477.
# torch.Size([1, 3, 1024])
# Processing item 5500.
# number 478.
# torch.Size([1, 3, 1024])
# Processing item 14296.
# number 479.
# torch.Size([1, 3, 1024])
# Processing item 10889.
# number 480.
# torch.Size([1, 3, 1024])
# Processing item 13179.
# number 481.
# torch.Size([1, 3, 1024])
# Processing item 134.
# number 482.
# torch.Size([1, 3, 1024])
# Processing item 3865.
# number 483.
# torch.Size([1, 3, 1024])
# Processing item 14965.
# number 484.
# torch.Size([1, 3, 1024])
# Processing item 16206.
# number 485.
# torch.Size([1, 3, 1024])
# Processing item 18181.
# number 486.
# torch.Size([1, 3, 1024])
# Processing item 16650.
# number 487.
# torch.Size([1, 3, 1024])
# Processing item 3071.
# number 488.
# torch.Size([1, 3, 1024])
# Processing item 13372.
# number 489.
# torch.Size([1, 3, 1024])
# Processing item 10884.
# number 490.
# torch.Size([1, 3, 1024])
# Processing item 3383.
# number 491.
# torch.Size([1, 3, 1024])
# Processing item 6896.
# number 492.
# torch.Size([1, 3, 1024])
# Processing item 4859.
# number 493.
# torch.Size([1, 3, 1024])
# Processing item 14222.
# number 494.
# torch.Size([1, 3, 1024])
# Processing item 18623.
# number 495.
# torch.Size([1, 3, 1024])
# Processing item 3011.
# number 496.
# torch.Size([1, 3, 1024])
# Processing item 981.
# number 497.
# torch.Size([1, 3, 1024])
# Processing item 635.
# number 498.
# torch.Size([1, 3, 1024])
# Processing item 17145.
# number 499.
# torch.Size([1, 3, 1024])
# Processing item 13001.
# number 500.
# torch.Size([1, 3, 1024])
# Processing item 8274.
# number 501.
# torch.Size([1, 3, 1024])
# Processing item 8943.
# number 502.
# torch.Size([1, 3, 1024])
# Processing item 898.
# number 503.
# torch.Size([1, 3, 1024])
# Processing item 12554.
# number 504.
# torch.Size([1, 3, 1024])
# Processing item 12446.
# number 505.
# torch.Size([1, 3, 1024])
# Processing item 1727.
# number 506.
# torch.Size([1, 3, 1024])
# Processing item 10733.
# number 507.
# torch.Size([1, 3, 1024])
# Processing item 17051.
# number 508.
# torch.Size([1, 3, 1024])
# Processing item 18797.
# number 509.
# torch.Size([1, 3, 1024])
# Processing item 12829.
# number 510.
# torch.Size([1, 3, 1024])
# Processing item 10250.
# number 511.
# torch.Size([1, 3, 1024])
# Processing item 13363.
# number 512.
# torch.Size([1, 3, 1024])
# Processing item 17792.
# number 513.
# torch.Size([1, 3, 1024])
# Processing item 8988.
# number 514.
# torch.Size([1, 3, 1024])
# Processing item 12954.
# number 515.
# torch.Size([1, 3, 1024])
# Processing item 17124.
# number 516.
# torch.Size([1, 3, 1024])
# Processing item 427.
# number 517.
# torch.Size([1, 3, 1024])
# Processing item 17448.
# number 518.
# torch.Size([1, 3, 1024])
# Processing item 2169.
# number 519.
# torch.Size([1, 3, 1024])
# Processing item 4658.
# number 520.
# torch.Size([1, 3, 1024])
# Processing item 8903.
# number 521.
# torch.Size([1, 3, 1024])
# Processing item 1730.
# number 522.
# torch.Size([1, 3, 1024])
# Processing item 12860.
# number 523.
# torch.Size([1, 3, 1024])
# Processing item 12799.
# number 524.
# torch.Size([1, 3, 1024])
# Processing item 10141.
# number 525.
# torch.Size([1, 3, 1024])
# Processing item 5993.
# number 526.
# torch.Size([1, 3, 1024])
# Processing item 3891.
# number 527.
# torch.Size([1, 3, 1024])
# Processing item 11765.
# number 528.
# torch.Size([1, 3, 1024])
# Processing item 3208.
# number 529.
# torch.Size([1, 3, 1024])
# Processing item 17138.
# number 530.
# torch.Size([1, 3, 1024])
# Processing item 10208.
# number 531.
# torch.Size([1, 3, 1024])
# Processing item 9511.
# number 532.
# torch.Size([1, 3, 1024])
# Processing item 9506.
# number 533.
# torch.Size([1, 3, 1024])
# Processing item 14615.
# number 534.
# torch.Size([1, 3, 1024])
# Processing item 11912.
# number 535.
# torch.Size([1, 3, 1024])
# Processing item 11092.
# number 536.
# torch.Size([1, 3, 1024])
# Processing item 7269.
# number 537.
# torch.Size([1, 3, 1024])
# Processing item 994.
# number 538.
# torch.Size([1, 3, 1024])
# Processing item 7605.
# number 539.
# torch.Size([1, 3, 1024])
# Processing item 3010.
# number 540.
# torch.Size([1, 3, 1024])
# Processing item 18647.
# number 541.
# torch.Size([1, 3, 1024])
# Processing item 18456.
# number 542.
# torch.Size([1, 3, 1024])
# Processing item 18197.
# number 543.
# torch.Size([1, 3, 1024])
# Processing item 2327.
# number 544.
# torch.Size([1, 3, 1024])
# Processing item 4096.
# number 545.
# torch.Size([1, 3, 1024])
# Processing item 1799.
# number 546.
# torch.Size([1, 3, 1024])
# Processing item 10110.
# number 547.
# torch.Size([1, 3, 1024])
# Processing item 3816.
# number 548.
# torch.Size([1, 3, 1024])
# Processing item 15434.
# number 549.
# torch.Size([1, 3, 1024])
# Processing item 18884.
# number 550.
# torch.Size([1, 3, 1024])
# Processing item 8761.
# number 551.
# torch.Size([1, 3, 1024])
# Processing item 7136.
# number 552.
# torch.Size([1, 3, 1024])
# Processing item 8145.
# number 553.
# torch.Size([1, 3, 1024])
# Processing item 1881.
# number 554.
# torch.Size([1, 3, 1024])
# Processing item 13453.
# number 555.
# torch.Size([1, 3, 1024])
# Processing item 3239.
# number 556.
# torch.Size([1, 3, 1024])
# Processing item 15717.
# number 557.
# torch.Size([1, 3, 1024])
# Processing item 2291.
# number 558.
# torch.Size([1, 3, 1024])
# Processing item 11614.
# number 559.
# torch.Size([1, 3, 1024])
# Processing item 14058.
# number 560.
# torch.Size([1, 3, 1024])
# Processing item 8530.
# number 561.
# torch.Size([1, 3, 1024])
# Processing item 10438.
# number 562.
# torch.Size([1, 3, 1024])
# Processing item 17305.
# number 563.
# torch.Size([1, 3, 1024])
# Processing item 3881.
# number 564.
# torch.Size([1, 3, 1024])
# Processing item 3790.
# number 565.
# torch.Size([1, 3, 1024])
# Processing item 13624.
# number 566.
# torch.Size([1, 3, 1024])
# Processing item 3463.
# number 567.
# torch.Size([1, 3, 1024])
# Processing item 17369.
# number 568.
# torch.Size([1, 3, 1024])
# Processing item 16701.
# number 569.
# torch.Size([1, 3, 1024])
# Processing item 32.
# number 570.
# torch.Size([1, 3, 1024])
# Processing item 13268.
# number 571.
# torch.Size([1, 3, 1024])
# Processing item 18938.
# number 572.
# torch.Size([1, 3, 1024])
# Processing item 11499.
# number 573.
# torch.Size([1, 3, 1024])
# Processing item 4150.
# number 574.
# torch.Size([1, 3, 1024])
# Processing item 48.
# number 575.
# torch.Size([1, 3, 1024])
# Processing item 2680.
# number 576.
# torch.Size([1, 3, 1024])
# Processing item 17517.
# number 577.
# torch.Size([1, 3, 1024])
# Processing item 14947.
# number 578.
# torch.Size([1, 3, 1024])
# Processing item 7194.
# number 579.
# torch.Size([1, 3, 1024])
# Processing item 4668.
# number 580.
# torch.Size([1, 3, 1024])
# Processing item 15446.
# number 581.
# torch.Size([1, 3, 1024])
# Processing item 17179.
# number 582.
# torch.Size([1, 3, 1024])
# Processing item 895.
# number 583.
# torch.Size([1, 3, 1024])
# Processing item 3638.
# number 584.
# torch.Size([1, 3, 1024])
# Processing item 7838.
# number 585.
# torch.Size([1, 3, 1024])
# Processing item 8221.
# number 586.
# torch.Size([1, 3, 1024])
# Processing item 12681.
# number 587.
# torch.Size([1, 3, 1024])
# Processing item 4478.
# number 588.
# torch.Size([1, 3, 1024])
# Processing item 12600.
# number 589.
# torch.Size([1, 3, 1024])
# Processing item 11838.
# number 590.
# torch.Size([1, 3, 1024])
# Processing item 18622.
# number 591.
# torch.Size([1, 3, 1024])
# Processing item 2123.
# number 592.
# torch.Size([1, 3, 1024])
# Processing item 12515.
# number 593.
# torch.Size([1, 3, 1024])
# Processing item 7990.
# number 594.
# torch.Size([1, 3, 1024])
# Processing item 14250.
# number 595.
# torch.Size([1, 3, 1024])
# Processing item 8809.
# number 596.
# torch.Size([1, 3, 1024])
# Processing item 19132.
# number 597.
# torch.Size([1, 3, 1024])
# Processing item 6992.
# number 598.
# torch.Size([1, 3, 1024])
# Processing item 1788.
# number 599.
# torch.Size([1, 3, 1024])
# Processing item 2424.
# number 600.
# torch.Size([1, 3, 1024])
# Processing item 5738.
# number 601.
# torch.Size([1, 3, 1024])
# Processing item 17266.
# number 602.
# torch.Size([1, 3, 1024])
# Processing item 13853.
# number 603.
# torch.Size([1, 3, 1024])
# Processing item 4378.
# number 604.
# torch.Size([1, 3, 1024])
# Processing item 18874.
# number 605.
# torch.Size([1, 3, 1024])
# Processing item 1147.
# number 606.
# torch.Size([1, 3, 1024])
# Processing item 10987.
# number 607.
# torch.Size([1, 3, 1024])
# Processing item 16792.
# number 608.
# torch.Size([1, 3, 1024])
# Processing item 17418.
# number 609.
# torch.Size([1, 3, 1024])
# Processing item 8189.
# number 610.
# torch.Size([1, 3, 1024])
# Processing item 17817.
# number 611.
# torch.Size([1, 3, 1024])
# Processing item 13919.
# number 612.
# torch.Size([1, 3, 1024])
# Processing item 2749.
# number 613.
# torch.Size([1, 3, 1024])
# Processing item 9960.
# number 614.
# torch.Size([1, 3, 1024])
# Processing item 444.
# number 615.
# torch.Size([1, 3, 1024])
# Processing item 17202.
# number 616.
# torch.Size([1, 3, 1024])
# Processing item 16109.
# number 617.
# torch.Size([1, 3, 1024])
# Processing item 10193.
# number 618.
# torch.Size([1, 3, 1024])
# Processing item 5725.
# number 619.
# torch.Size([1, 3, 1024])
# Processing item 19513.
# number 620.
# torch.Size([1, 3, 1024])
# Processing item 15778.
# number 621.
# torch.Size([1, 3, 1024])
# Processing item 6493.
# number 622.
# torch.Size([1, 3, 1024])
# Processing item 2734.
# number 623.
# torch.Size([1, 3, 1024])
# Processing item 13165.
# number 624.
# torch.Size([1, 3, 1024])
# Processing item 13938.
# number 625.
# torch.Size([1, 3, 1024])
# Processing item 10170.
# number 626.
# torch.Size([1, 3, 1024])
# Processing item 12238.
# number 627.
# torch.Size([1, 3, 1024])
# Processing item 15318.
# number 628.
# torch.Size([1, 3, 1024])
# Processing item 15491.
# number 629.
# torch.Size([1, 3, 1024])
# Processing item 9983.
# number 630.
# torch.Size([1, 3, 1024])
# Processing item 3836.
# number 631.
# torch.Size([1, 3, 1024])
# Processing item 14501.
# number 632.
# torch.Size([1, 3, 1024])
# Processing item 15205.
# number 633.
# torch.Size([1, 3, 1024])
# Processing item 14160.
# number 634.
# torch.Size([1, 3, 1024])
# Processing item 1656.
# number 635.
# torch.Size([1, 3, 1024])
# Processing item 13847.
# number 636.
# torch.Size([1, 3, 1024])
# Processing item 6669.
# number 637.
# torch.Size([1, 3, 1024])
# Processing item 8140.
# number 638.
# torch.Size([1, 3, 1024])
# Processing item 16584.
# number 639.
# torch.Size([1, 3, 1024])
# Processing item 139.
# number 640.
# torch.Size([1, 3, 1024])
# Processing item 4860.
# number 641.
# torch.Size([1, 3, 1024])
# Processing item 14837.
# number 642.
# torch.Size([1, 3, 1024])
# Processing item 11095.
# number 643.
# torch.Size([1, 3, 1024])
# Processing item 13566.
# number 644.
# torch.Size([1, 3, 1024])
# Processing item 9976.
# number 645.
# torch.Size([1, 3, 1024])
# Processing item 9883.
# number 646.
# torch.Size([1, 3, 1024])
# Processing item 1486.
# number 647.
# torch.Size([1, 3, 1024])
# Processing item 2012.
# number 648.
# torch.Size([1, 3, 1024])
# Processing item 12739.
# number 649.
# torch.Size([1, 3, 1024])
# Processing item 98.
# number 650.
# torch.Size([1, 3, 1024])
# Processing item 8295.
# number 651.
# torch.Size([1, 3, 1024])
# Processing item 19604.
# number 652.
# torch.Size([1, 3, 1024])
# Processing item 16934.
# number 653.
# torch.Size([1, 3, 1024])
# Processing item 11036.
# number 654.
# torch.Size([1, 3, 1024])
# Processing item 12566.
# number 655.
# torch.Size([1, 3, 1024])
# Processing item 1563.
# number 656.
# torch.Size([1, 3, 1024])
# Processing item 2357.
# number 657.
# torch.Size([1, 3, 1024])
# Processing item 8358.
# number 658.
# torch.Size([1, 3, 1024])
# Processing item 7718.
# number 659.
# torch.Size([1, 3, 1024])
# Processing item 11832.
# number 660.
# torch.Size([1, 3, 1024])
# Processing item 4571.
# number 661.
# torch.Size([1, 3, 1024])
# Processing item 14210.
# number 662.
# torch.Size([1, 3, 1024])
# Processing item 18813.
# number 663.
# torch.Size([1, 3, 1024])
# Processing item 1435.
# number 664.
# torch.Size([1, 3, 1024])
# Processing item 8646.
# number 665.
# torch.Size([1, 3, 1024])
# Processing item 7801.
# number 666.
# torch.Size([1, 3, 1024])
# Processing item 4055.
# number 667.
# torch.Size([1, 3, 1024])
# Processing item 16573.
# number 668.
# torch.Size([1, 3, 1024])
# Processing item 13411.
# number 669.
# torch.Size([1, 3, 1024])
# Processing item 14614.
# number 670.
# torch.Size([1, 3, 1024])
# Processing item 2811.
# number 671.
# torch.Size([1, 3, 1024])
# Processing item 2240.
# number 672.
# torch.Size([1, 3, 1024])
# Processing item 3761.
# number 673.
# torch.Size([1, 3, 1024])
# Processing item 16803.
# number 674.
# torch.Size([1, 3, 1024])
# Processing item 13292.
# number 675.
# torch.Size([1, 3, 1024])
# Processing item 5654.
# number 676.
# torch.Size([1, 3, 1024])
# Processing item 15001.
# number 677.
# torch.Size([1, 3, 1024])
# Processing item 18200.
# number 678.
# torch.Size([1, 3, 1024])
# Processing item 14191.
# number 679.
# torch.Size([1, 3, 1024])
# Processing item 14159.
# number 680.
# torch.Size([1, 3, 1024])
# Processing item 3598.
# number 681.
# torch.Size([1, 3, 1024])
# Processing item 15695.
# number 682.
# torch.Size([1, 3, 1024])
# Processing item 9104.
# number 683.
# torch.Size([1, 3, 1024])
# Processing item 5347.
# number 684.
# torch.Size([1, 3, 1024])
# Processing item 2623.
# number 685.
# torch.Size([1, 3, 1024])
# Processing item 14699.
# number 686.
# torch.Size([1, 3, 1024])
# Processing item 18445.
# number 687.
# torch.Size([1, 3, 1024])
# Processing item 1156.
# number 688.
# torch.Size([1, 3, 1024])
# Processing item 2863.
# number 689.
# torch.Size([1, 3, 1024])
# Processing item 12814.
# number 690.
# torch.Size([1, 3, 1024])
# Processing item 8044.
# number 691.
# torch.Size([1, 3, 1024])
# Processing item 320.
# number 692.
# torch.Size([1, 3, 1024])
# Processing item 1039.
# number 693.
# torch.Size([1, 3, 1024])
# Processing item 4173.
# number 694.
# torch.Size([1, 3, 1024])
# Processing item 9129.
# number 695.
# torch.Size([1, 3, 1024])
# Processing item 11268.
# number 696.
# torch.Size([1, 3, 1024])
# Processing item 12948.
# number 697.
# torch.Size([1, 3, 1024])
# Processing item 1205.
# number 698.
# torch.Size([1, 3, 1024])
# Processing item 19673.
# number 699.
# torch.Size([1, 3, 1024])
# Processing item 2597.
# number 700.
# torch.Size([1, 3, 1024])
# Processing item 6520.
# number 701.
# torch.Size([1, 3, 1024])
# Processing item 5926.
# number 702.
# torch.Size([1, 3, 1024])
# Processing item 10681.
# number 703.
# torch.Size([1, 3, 1024])
# Processing item 901.
# number 704.
# torch.Size([1, 3, 1024])
# Processing item 2673.
# number 705.
# torch.Size([1, 3, 1024])
# Processing item 12302.
# number 706.
# torch.Size([1, 3, 1024])
# Processing item 3159.
# number 707.
# torch.Size([1, 3, 1024])
# Processing item 14341.
# number 708.
# torch.Size([1, 3, 1024])
# Processing item 1958.
# number 709.
# torch.Size([1, 3, 1024])
# Processing item 7578.
# number 710.
# torch.Size([1, 3, 1024])
# Processing item 5327.
# number 711.
# torch.Size([1, 3, 1024])
# Processing item 16599.
# number 712.
# torch.Size([1, 3, 1024])
# Processing item 8941.
# number 713.
# torch.Size([1, 3, 1024])
# Processing item 6973.
# number 714.
# torch.Size([1, 3, 1024])
# Processing item 15541.
# number 715.
# torch.Size([1, 3, 1024])
# Processing item 3390.
# number 716.
# torch.Size([1, 3, 1024])
# Processing item 9048.
# number 717.
# torch.Size([1, 3, 1024])
# Processing item 3161.
# number 718.
# torch.Size([1, 3, 1024])
# Processing item 1961.
# number 719.
# torch.Size([1, 3, 1024])
# Processing item 16048.
# number 720.
# torch.Size([1, 3, 1024])
# Processing item 2520.
# number 721.
# torch.Size([1, 3, 1024])
# Processing item 2838.
# number 722.
# torch.Size([1, 3, 1024])
# Processing item 10083.
# number 723.
# torch.Size([1, 3, 1024])
# Processing item 12819.
# number 724.
# torch.Size([1, 3, 1024])
# Processing item 2277.
# number 725.
# torch.Size([1, 3, 1024])
# Processing item 2582.
# number 726.
# torch.Size([1, 3, 1024])
# Processing item 8097.
# number 727.
# torch.Size([1, 3, 1024])
# Processing item 13993.
# number 728.
# torch.Size([1, 3, 1024])
# Processing item 8930.
# number 729.
# torch.Size([1, 3, 1024])
# Processing item 9413.
# number 730.
# torch.Size([1, 3, 1024])
# Processing item 13858.
# number 731.
# torch.Size([1, 3, 1024])
# Processing item 10344.
# number 732.
# torch.Size([1, 3, 1024])
# Processing item 12135.
# number 733.
# torch.Size([1, 3, 1024])
# Processing item 16227.
# number 734.
# torch.Size([1, 3, 1024])
# Processing item 4791.
# number 735.
# torch.Size([1, 3, 1024])
# Processing item 4765.
# number 736.
# torch.Size([1, 3, 1024])
# Processing item 16510.
# number 737.
# torch.Size([1, 3, 1024])
# Processing item 15832.
# number 738.
# torch.Size([1, 3, 1024])
# Processing item 18764.
# number 739.
# torch.Size([1, 3, 1024])
# Processing item 18092.
# number 740.
# torch.Size([1, 3, 1024])
# Processing item 8939.
# number 741.
# torch.Size([1, 3, 1024])
# Processing item 11394.
# number 742.
# torch.Size([1, 3, 1024])
# Processing item 13475.
# number 743.
# torch.Size([1, 3, 1024])
# Processing item 13270.
# number 744.
# torch.Size([1, 3, 1024])
# Processing item 13927.
# number 745.
# torch.Size([1, 3, 1024])
# Processing item 16254.
# number 746.
# torch.Size([1, 3, 1024])
# Processing item 2840.
# number 747.
# torch.Size([1, 3, 1024])
# Processing item 9260.
# number 748.
# torch.Size([1, 3, 1024])
# Processing item 19360.
# number 749.
# torch.Size([1, 3, 1024])
# Processing item 15007.
# number 750.
# torch.Size([1, 3, 1024])
# Processing item 2237.
# number 751.
# torch.Size([1, 3, 1024])
# Processing item 13042.
# number 752.
# torch.Size([1, 3, 1024])
# Processing item 17301.
# number 753.
# torch.Size([1, 3, 1024])
# Processing item 6170.
# number 754.
# torch.Size([1, 3, 1024])
# Processing item 9776.
# number 755.
# torch.Size([1, 3, 1024])
# Processing item 4767.
# number 756.
# torch.Size([1, 3, 1024])
# Processing item 6398.
# number 757.
# torch.Size([1, 3, 1024])
# Processing item 17758.
# number 758.
# torch.Size([1, 3, 1024])
# Processing item 12067.
# number 759.
# torch.Size([1, 3, 1024])
# Processing item 4263.
# number 760.
# torch.Size([1, 3, 1024])
# Processing item 15130.
# number 761.
# torch.Size([1, 3, 1024])
# Processing item 16311.
# number 762.
# torch.Size([1, 3, 1024])
# Processing item 129.
# number 763.
# torch.Size([1, 3, 1024])
# Processing item 16148.
# number 764.
# torch.Size([1, 3, 1024])
# Processing item 17107.
# number 765.
# torch.Size([1, 3, 1024])
# Processing item 9443.
# number 766.
# torch.Size([1, 3, 1024])
# Processing item 16601.
# number 767.
# torch.Size([1, 3, 1024])
# Processing item 1009.
# number 768.
# torch.Size([1, 3, 1024])
# Processing item 17485.
# number 769.
# torch.Size([1, 3, 1024])
# Processing item 16228.
# number 770.
# torch.Size([1, 3, 1024])
# Processing item 10708.
# number 771.
# torch.Size([1, 3, 1024])
# Processing item 17336.
# number 772.
# torch.Size([1, 3, 1024])
# Processing item 2679.
# number 773.
# torch.Size([1, 3, 1024])
# Processing item 13128.
# number 774.
# torch.Size([1, 3, 1024])
# Processing item 10262.
# number 775.
# torch.Size([1, 3, 1024])
# Processing item 920.
# number 776.
# torch.Size([1, 3, 1024])
# Processing item 3213.
# number 777.
# torch.Size([1, 3, 1024])
# Processing item 97.
# number 778.
# torch.Size([1, 3, 1024])
# Processing item 16185.
# number 779.
# torch.Size([1, 3, 1024])
# Processing item 11199.
# number 780.
# torch.Size([1, 3, 1024])
# Processing item 16686.
# number 781.
# torch.Size([1, 3, 1024])
# Processing item 3070.
# number 782.
# torch.Size([1, 3, 1024])
# Processing item 2193.
# number 783.
# torch.Size([1, 3, 1024])
# Processing item 523.
# number 784.
# torch.Size([1, 3, 1024])
# Processing item 738.
# number 785.
# torch.Size([1, 3, 1024])
# Processing item 2524.
# number 786.
# torch.Size([1, 3, 1024])
# Processing item 6668.
# number 787.
# torch.Size([1, 3, 1024])
# Processing item 26.
# number 788.
# torch.Size([1, 3, 1024])
# Processing item 19096.
# number 789.
# torch.Size([1, 3, 1024])
# Processing item 17798.
# number 790.
# torch.Size([1, 3, 1024])
# Processing item 2005.
# number 791.
# torch.Size([1, 3, 1024])
# Processing item 11952.
# number 792.
# torch.Size([1, 3, 1024])
# Processing item 15485.
# number 793.
# torch.Size([1, 3, 1024])
# Processing item 6140.
# number 794.
# torch.Size([1, 3, 1024])
# Processing item 15696.
# number 795.
# torch.Size([1, 3, 1024])
# Processing item 7934.
# number 796.
# torch.Size([1, 3, 1024])
# Processing item 1405.
# number 797.
# torch.Size([1, 3, 1024])
# Processing item 18822.
# number 798.
# torch.Size([1, 3, 1024])
# Processing item 113.
# number 799.
# torch.Size([1, 3, 1024])
# Processing item 2213.
# number 800.
# torch.Size([1, 3, 1024])
# Processing item 6509.
# number 801.
# torch.Size([1, 3, 1024])
# Processing item 11118.
# number 802.
# torch.Size([1, 3, 1024])
# Processing item 16974.
# number 803.
# torch.Size([1, 3, 1024])
# Processing item 12011.
# number 804.
# ...
# torch.Size([1, 3, 1024])
# Processing item 17775.
# number 19480.
# torch.Size([1, 3, 1024])
# Processing item 19182.
# number 19481.
# torch.Size([1, 3, 1024])
# Processing item 2788.
# number 19482.
# torch.Size([1, 3, 1024])
# Processing item 7192.
# number 19483.
# torch.Size([1, 3, 1024])
# Processing item 15559.
# number 19484.
# torch.Size([1, 3, 1024])
# Processing item 17322.
# number 19485.
# torch.Size([1, 3, 1024])
# Processing item 9042.
# number 19486.
# torch.Size([1, 3, 1024])
# Processing item 9229.
# number 19487.
# torch.Size([1, 3, 1024])
# Processing item 1359.
# number 19488.
# torch.Size([1, 3, 1024])
# Processing item 8560.
# number 19489.
# torch.Size([1, 3, 1024])
# Processing item 2194.
# number 19490.
# torch.Size([1, 3, 1024])
# Processing item 13356.
# number 19491.
# torch.Size([1, 3, 1024])
# Processing item 5301.
# number 19492.
# torch.Size([1, 3, 1024])
# Processing item 6064.
# number 19493.
# torch.Size([1, 3, 1024])
# Processing item 11617.
# number 19494.
# torch.Size([1, 3, 1024])
# Processing item 18558.
# number 19495.
# torch.Size([1, 3, 1024])
# Processing item 5669.
# number 19496.
# torch.Size([1, 3, 1024])
# Processing item 6756.
# number 19497.
# torch.Size([1, 3, 1024])
# Processing item 18407.
# number 19498.
# torch.Size([1, 3, 1024])
# Processing item 12745.
# number 19499.
# torch.Size([1, 3, 1024])
# Processing item 1002.
# number 19500.
# torch.Size([1, 3, 1024])
# Processing item 7992.
# number 19501.
# torch.Size([1, 3, 1024])
# Processing item 6590.
# number 19502.
# torch.Size([1, 3, 1024])
# Processing item 16706.
# number 19503.
# torch.Size([1, 3, 1024])
# Processing item 3679.
# number 19504.
# torch.Size([1, 3, 1024])
# Processing item 18410.
# number 19505.
# torch.Size([1, 3, 1024])
# Processing item 12093.
# number 19506.
# torch.Size([1, 3, 1024])
# Processing item 5192.
# number 19507.
# torch.Size([1, 3, 1024])
# Processing item 10548.
# number 19508.
# torch.Size([1, 3, 1024])
# Processing item 5659.
# number 19509.
# torch.Size([1, 3, 1024])
# Processing item 18745.
# number 19510.
# torch.Size([1, 3, 1024])
# Processing item 6094.
# number 19511.
# torch.Size([1, 3, 1024])
# Processing item 19654.
# number 19512.
# torch.Size([1, 3, 1024])
# Processing item 7207.
# number 19513.
# torch.Size([1, 3, 1024])
# Processing item 9099.
# number 19514.
# torch.Size([1, 3, 1024])
# Processing item 12763.
# number 19515.
# torch.Size([1, 3, 1024])
# Processing item 9489.
# number 19516.
# torch.Size([1, 3, 1024])
# Processing item 15400.
# number 19517.
# torch.Size([1, 3, 1024])
# Processing item 11327.
# number 19518.
# torch.Size([1, 3, 1024])
# Processing item 1463.
# number 19519.
# torch.Size([1, 3, 1024])
# Processing item 2137.
# number 19520.
# torch.Size([1, 3, 1024])
# Processing item 64.
# number 19521.
# torch.Size([1, 3, 1024])
# Processing item 2646.
# number 19522.
# torch.Size([1, 3, 1024])
# Processing item 12210.
# number 19523.
# torch.Size([1, 3, 1024])
# Processing item 12205.
# number 19524.
# torch.Size([1, 3, 1024])
# Processing item 18598.
# number 19525.
# torch.Size([1, 3, 1024])
# Processing item 18228.
# number 19526.
# torch.Size([1, 3, 1024])
# Processing item 9183.
# number 19527.
# torch.Size([1, 3, 1024])
# Processing item 2099.
# number 19528.
# torch.Size([1, 3, 1024])
# Processing item 16764.
# number 19529.
# torch.Size([1, 3, 1024])
# Processing item 7373.
# number 19530.
# torch.Size([1, 3, 1024])
# Processing item 8687.
# number 19531.
# torch.Size([1, 3, 1024])
# Processing item 1662.
# number 19532.
# torch.Size([1, 3, 1024])
# Processing item 16920.
# number 19533.
# torch.Size([1, 3, 1024])
# Processing item 14380.
# number 19534.
# torch.Size([1, 3, 1024])
# Processing item 1612.
# number 19535.
# torch.Size([1, 3, 1024])
# Processing item 10281.
# number 19536.
# torch.Size([1, 3, 1024])
# Processing item 2806.
# number 19537.
# torch.Size([1, 3, 1024])
# Processing item 17998.
# number 19538.
# torch.Size([1, 3, 1024])
# Processing item 5001.
# number 19539.
# torch.Size([1, 3, 1024])
# Processing item 5939.
# number 19540.
# torch.Size([1, 3, 1024])
# Processing item 18097.
# number 19541.
# torch.Size([1, 3, 1024])
# Processing item 5307.
# number 19542.
# torch.Size([1, 3, 1024])
# Processing item 10008.
# number 19543.
# torch.Size([1, 3, 1024])
# Processing item 1974.
# number 19544.
# torch.Size([1, 3, 1024])
# Processing item 17218.
# number 19545.
# torch.Size([1, 3, 1024])
# Processing item 7559.
# number 19546.
# torch.Size([1, 3, 1024])
# Processing item 10836.
# number 19547.
# torch.Size([1, 3, 1024])
# Processing item 14458.
# number 19548.
# torch.Size([1, 3, 1024])
# Processing item 15319.
# number 19549.
# torch.Size([1, 3, 1024])
# Processing item 5260.
# number 19550.
# torch.Size([1, 3, 1024])
# Processing item 1660.
# number 19551.
# torch.Size([1, 3, 1024])
# Processing item 792.
# number 19552.
# torch.Size([1, 3, 1024])
# Processing item 3993.
# number 19553.
# torch.Size([1, 3, 1024])
# Processing item 1461.
# number 19554.
# torch.Size([1, 3, 1024])
# Processing item 15988.
# number 19555.
# torch.Size([1, 3, 1024])
# Processing item 11117.
# number 19556.
# torch.Size([1, 3, 1024])
# Processing item 2370.
# number 19557.
# torch.Size([1, 3, 1024])
# Processing item 11772.
# number 19558.
# torch.Size([1, 3, 1024])
# Processing item 3851.
# number 19559.
# torch.Size([1, 3, 1024])
# Processing item 6903.
# number 19560.
# torch.Size([1, 3, 1024])
# Processing item 12698.
# number 19561.
# torch.Size([1, 3, 1024])
# Processing item 7482.
# number 19562.
# torch.Size([1, 3, 1024])
# Processing item 17053.
# number 19563.
# torch.Size([1, 3, 1024])
# Processing item 19537.
# number 19564.
# torch.Size([1, 3, 1024])
# Processing item 156.
# number 19565.
# torch.Size([1, 3, 1024])
# Processing item 2969.
# number 19566.
# torch.Size([1, 3, 1024])
# Processing item 13265.
# number 19567.
# torch.Size([1, 3, 1024])
# Processing item 16616.
# number 19568.
# torch.Size([1, 3, 1024])
# Processing item 3821.
# number 19569.
# torch.Size([1, 3, 1024])
# Processing item 13182.
# number 19570.
# torch.Size([1, 3, 1024])
# Processing item 18781.
# number 19571.
# torch.Size([1, 3, 1024])
# Processing item 13209.
# number 19572.
# torch.Size([1, 3, 1024])
# Processing item 12294.
# number 19573.
# torch.Size([1, 3, 1024])
# Processing item 8371.
# number 19574.
# torch.Size([1, 3, 1024])
# Processing item 10736.
# number 19575.
# torch.Size([1, 3, 1024])
# Processing item 16061.
# number 19576.
# torch.Size([1, 3, 1024])
# Processing item 7581.
# number 19577.
# torch.Size([1, 3, 1024])
# Processing item 634.
# number 19578.
# torch.Size([1, 3, 1024])
# Processing item 1467.
# number 19579.
# torch.Size([1, 3, 1024])
# Processing item 2770.
# number 19580.
# torch.Size([1, 3, 1024])
# Processing item 11819.
# number 19581.
# torch.Size([1, 3, 1024])
# Processing item 14097.
# number 19582.
# torch.Size([1, 3, 1024])
# Processing item 15228.
# number 19583.
# torch.Size([1, 3, 1024])
# Processing item 4558.
# number 19584.
# torch.Size([1, 3, 1024])
# Processing item 461.
# number 19585.
# torch.Size([1, 3, 1024])
# Processing item 7782.
# number 19586.
# torch.Size([1, 3, 1024])
# Processing item 4051.
# number 19587.
# torch.Size([1, 3, 1024])
# Processing item 17796.
# number 19588.
# torch.Size([1, 3, 1024])
# Processing item 1904.
# number 19589.
# torch.Size([1, 3, 1024])
# Processing item 6839.
# number 19590.
# torch.Size([1, 3, 1024])
# Processing item 3560.
# number 19591.
# torch.Size([1, 3, 1024])
# Processing item 14101.
# number 19592.
# torch.Size([1, 3, 1024])
# Processing item 9987.
# number 19593.
# torch.Size([1, 3, 1024])
# Processing item 7654.
# number 19594.
# torch.Size([1, 3, 1024])
# Processing item 5489.
# number 19595.
# torch.Size([1, 3, 1024])
# Processing item 10204.
# number 19596.
# torch.Size([1, 3, 1024])
# Processing item 16104.
# number 19597.
# torch.Size([1, 3, 1024])
# Processing item 2385.
# number 19598.
# torch.Size([1, 3, 1024])
# Processing item 14204.
# number 19599.
# torch.Size([1, 3, 1024])
# Processing item 6900.
# number 19600.
# torch.Size([1, 3, 1024])
# Processing item 15106.
# number 19601.
# torch.Size([1, 3, 1024])
# Processing item 3361.
# number 19602.
# torch.Size([1, 3, 1024])
# Processing item 16151.
# number 19603.
# torch.Size([1, 3, 1024])
# Processing item 7497.
# number 19604.
# torch.Size([1, 3, 1024])
# Processing item 12341.
# number 19605.
# torch.Size([1, 3, 1024])
# Processing item 2371.
# number 19606.
# torch.Size([1, 3, 1024])
# Processing item 11924.
# number 19607.
# torch.Size([1, 3, 1024])
# Processing item 4870.
# number 19608.
# torch.Size([1, 3, 1024])
# Processing item 10136.
# number 19609.
# torch.Size([1, 3, 1024])
# Processing item 6915.
# number 19610.
# torch.Size([1, 3, 1024])
# Processing item 15500.
# number 19611.
# torch.Size([1, 3, 1024])
# Processing item 11993.
# number 19612.
# torch.Size([1, 3, 1024])
# Processing item 4578.
# number 19613.
# torch.Size([1, 3, 1024])
# Processing item 9163.
# number 19614.
# torch.Size([1, 3, 1024])
# Processing item 17001.
# number 19615.
# torch.Size([1, 3, 1024])
# Processing item 18743.
# number 19616.
# torch.Size([1, 3, 1024])
# Processing item 11188.
# number 19617.
# torch.Size([1, 3, 1024])
# Processing item 10532.
# number 19618.
# torch.Size([1, 3, 1024])
# Processing item 5401.
# number 19619.
# torch.Size([1, 3, 1024])
# Processing item 15965.
# number 19620.
# torch.Size([1, 3, 1024])
# Processing item 6198.
# number 19621.
# torch.Size([1, 3, 1024])
# Processing item 6238.
# number 19622.
# torch.Size([1, 3, 1024])
# Processing item 6745.
# number 19623.
# torch.Size([1, 3, 1024])
# Processing item 19281.
# number 19624.
# torch.Size([1, 3, 1024])
# Processing item 17778.
# number 19625.
# torch.Size([1, 3, 1024])
# Processing item 12952.
# number 19626.
# torch.Size([1, 3, 1024])
# Processing item 4412.
# number 19627.
# torch.Size([1, 3, 1024])
# Processing item 18935.
# number 19628.
# torch.Size([1, 3, 1024])
# Processing item 3021.
# number 19629.
# torch.Size([1, 3, 1024])
# Processing item 13342.
# number 19630.
# torch.Size([1, 3, 1024])
# Processing item 11378.
# number 19631.
# torch.Size([1, 3, 1024])
# Processing item 16464.
# number 19632.
# torch.Size([1, 3, 1024])
# Processing item 11178.
# number 19633.
# torch.Size([1, 3, 1024])
# Processing item 4456.
# number 19634.
# torch.Size([1, 3, 1024])
# Processing item 16535.
# number 19635.
# torch.Size([1, 3, 1024])
# Processing item 15070.
# number 19636.
# torch.Size([1, 3, 1024])
# Processing item 7436.
# number 19637.
# torch.Size([1, 3, 1024])
# Processing item 17225.
# number 19638.
# torch.Size([1, 3, 1024])
# Processing item 18450.
# number 19639.
# torch.Size([1, 3, 1024])
# Processing item 1560.
# number 19640.
# torch.Size([1, 3, 1024])
# Processing item 7037.
# number 19641.
# torch.Size([1, 3, 1024])
# Processing item 19217.
# number 19642.
# torch.Size([1, 3, 1024])
# Processing item 15182.
# number 19643.
# torch.Size([1, 3, 1024])
# Processing item 11852.
# number 19644.
# torch.Size([1, 3, 1024])
# Processing item 995.
# number 19645.
# torch.Size([1, 3, 1024])
# Processing item 9384.
# number 19646.
# torch.Size([1, 3, 1024])
# Processing item 13440.
# number 19647.
# torch.Size([1, 3, 1024])
# Processing item 1229.
# number 19648.
# torch.Size([1, 3, 1024])
# Processing item 17946.
# number 19649.
# torch.Size([1, 3, 1024])
# Processing item 11297.
# number 19650.
# torch.Size([1, 3, 1024])
# Processing item 2469.
# number 19651.
# torch.Size([1, 3, 1024])
# Processing item 16155.
# number 19652.
# torch.Size([1, 3, 1024])
# Processing item 5588.
# number 19653.
# torch.Size([1, 3, 1024])
# Processing item 5645.
# number 19654.
# torch.Size([1, 3, 1024])
# Processing item 15280.
# number 19655.
# torch.Size([1, 3, 1024])
# Processing item 7254.
# number 19656.
# torch.Size([1, 3, 1024])
# Processing item 19569.
# number 19657.
# torch.Size([1, 3, 1024])
# Processing item 16736.
# number 19658.
# torch.Size([1, 3, 1024])
# Processing item 8868.
# number 19659.
# torch.Size([1, 3, 1024])
# Processing item 18249.
# number 19660.
# torch.Size([1, 3, 1024])
# Processing item 14029.
# number 19661.
# torch.Size([1, 3, 1024])
# Processing item 5782.
# number 19662.
# torch.Size([1, 3, 1024])
# Processing item 5462.
# number 19663.
# torch.Size([1, 3, 1024])
# Processing item 1411.
# number 19664.
# torch.Size([1, 3, 1024])
# Processing item 15807.
# number 19665.
# torch.Size([1, 3, 1024])
# Processing item 3772.
# number 19666.
# torch.Size([1, 3, 1024])
# Processing item 18119.
# number 19667.
# torch.Size([1, 3, 1024])
# Processing item 15899.
# number 19668.
# torch.Size([1, 3, 1024])
# Processing item 5165.
# number 19669.
# torch.Size([1, 3, 1024])
# Processing item 18440.
# number 19670.
# torch.Size([1, 3, 1024])
# Processing item 14343.
# number 19671.
# torch.Size([1, 3, 1024])
# Processing item 8203.
# number 19672.
# torch.Size([1, 3, 1024])
# Processing item 15865.
# number 19673.
# torch.Size([1, 3, 1024])
# Processing item 4950.
# number 19674.
# torch.Size([1, 3, 1024])
# Processing item 12056.
# number 19675.
# torch.Size([1, 3, 1024])
# Processing item 504.
# number 19676.
# torch.Size([1, 3, 1024])
# Processing item 6659.
# number 19677.
# torch.Size([1, 3, 1024])
# Processing item 13353.
# number 19678.
# torch.Size([1, 3, 1024])
# Processing item 8660.
# number 19679.
# torch.Size([1, 3, 1024])
# Processing item 6251.
# number 19680.
# torch.Size([1, 3, 1024])
# Processing item 13523.
# number 19681.
# torch.Size([1, 3, 1024])
# Processing item 4538.
# number 19682.
# torch.Size([1, 3, 1024])
# Processing item 17063.
# number 19683.
# torch.Size([1, 3, 1024])
# Processing item 194.
# number 19684.
# torch.Size([1, 3, 1024])
# Processing item 7276.
# number 19685.
# torch.Size([1, 3, 1024])
# Processing item 11576.
# number 19686.
# torch.Size([1, 3, 1024])
# Processing item 13426.
# number 19687.
# torch.Size([1, 3, 1024])
# Processing item 7038.
# number 19688.
# torch.Size([1, 3, 1024])
# Processing item 4612.
# number 19689.
# torch.Size([1, 3, 1024])
# Processing item 13231.
# number 19690.
# torch.Size([1, 3, 1024])
# Processing item 10913.
# number 19691.
# torch.Size([1, 3, 1024])
# Processing item 17539.
# number 19692.
# torch.Size([1, 3, 1024])
# Processing item 464.
# number 19693.
# torch.Size([1, 3, 1024])
# Processing item 2569.
# number 19694.
# torch.Size([1, 3, 1024])
# Processing item 17843.
# number 19695.
# torch.Size([1, 3, 1024])
# Processing item 5740.
# number 19696.
# torch.Size([1, 3, 1024])
# Processing item 7548.
# number 19697.
# torch.Size([1, 3, 1024])
# Processing item 7455.
# number 19698.
# torch.Size([1, 3, 1024])
# Processing item 15317.
# number 19699.
# torch.Size([1, 3, 1024])
# Processing item 8109.
# number 19700.
# torch.Size([1, 3, 1024])
# Processing item 4262.
# number 19701.
# torch.Size([1, 3, 1024])
# Processing item 15779.
# number 19702.
# torch.Size([1, 3, 1024])
# Processing item 4924.
# number 19703.
# torch.Size([1, 3, 1024])
# Processing item 15266.
# number 19704.
# torch.Size([1, 3, 1024])
# Processing item 17374.
# number 19705.
# torch.Size([1, 3, 1024])
# Processing item 4865.
# number 19706.
# torch.Size([1, 3, 1024])
# Processing item 3313.
# number 19707.
# torch.Size([1, 3, 1024])
# Processing item 8518.
# number 19708.
# torch.Size([1, 3, 1024])
# Processing item 7981.
# number 19709.
# torch.Size([1, 3, 1024])
# Processing item 2546.
# number 19710.
# torch.Size([1, 3, 1024])
# Processing item 6112.
# number 19711.
# torch.Size([1, 3, 1024])
# Processing item 12961.
# number 19712.
# torch.Size([1, 3, 1024])
# Processing item 7695.
# number 19713.
# torch.Size([1, 3, 1024])
# Processing item 11464.
# number 19714.
# torch.Size([1, 3, 1024])
# Processing item 1481.
# number 19715.
# torch.Size([1, 3, 1024])
# Processing item 5224.
# number 19716.
# torch.Size([1, 3, 1024])
# Processing item 2717.
# number 19717.
# torch.Size([1, 3, 1024])
# Processing item 16711.
# number 19718.
# torch.Size([1, 3, 1024])
# Processing item 5572.
# number 19719.
# torch.Size([1, 3, 1024])
# Processing item 998.
# number 19720.
# torch.Size([1, 3, 1024])
# Processing item 10049.
# number 19721.
# torch.Size([1, 3, 1024])
# Processing item 8657.
# number 19722.
# torch.Size([1, 3, 1024])
# Processing item 9505.
# number 19723.
# torch.Size([1, 3, 1024])
# Processing item 7475.
# number 19724.
# torch.Size([1, 3, 1024])
# Processing item 13446.
# number 19725.
# torch.Size([1, 3, 1024])
# Processing item 1406.
# number 19726.
# torch.Size([1, 3, 1024])
# Processing item 13755.
# number 19727.
# torch.Size([1, 3, 1024])
# Processing item 9596.
# number 19728.
# torch.Size([1, 3, 1024])
# Processing item 5127.
# number 19729.
# torch.Size([1, 3, 1024])
# Processing item 13095.
# number 19730.
# torch.Size([1, 3, 1024])
# Processing item 7241.
# number 19731.
# torch.Size([1, 3, 1024])
# Processing item 9359.
# number 19732.
# torch.Size([1, 3, 1024])
# Processing item 9212.
# number 19733.
# torch.Size([1, 3, 1024])
# Processing item 15155.
# number 19734.
# torch.Size([1, 3, 1024])
# Processing item 5145.
# number 19735.
# torch.Size([1, 3, 1024])
# Processing item 9110.
# number 19736.
# torch.Size([1, 3, 1024])
# Processing item 13385.
# number 19737.
# torch.Size([1, 3, 1024])
# Processing item 13965.
# number 19738.
# torch.Size([1, 3, 1024])
# All features extracted and saved into a single file!

# %%
all_features_array.shape
# Out:
# (19738, 3, 1024)

# %%
npy_file_path = 'oral_video_feat.npy'  # Change this to your file's path
npy_array = np.load(npy_file_path)

# Modify the array dimensions by averaging over the second dimension
npy_array_modified = npy_array.mean(axis=1)

# Optionally, save the modified array back to a file
modified_npy_file_path = 'video_feat.npy'  # Change this to your desired output file's path
np.save(modified_npy_file_path, npy_array_modified)

# If you want to check or use the modified array's shape
print(f"Modified array shape: {npy_array_modified.shape}")
# Out:
# Modified array shape: (19738, 1024)

# %%
import numpy as np

# Load the .npy file
original_data = np.load('oral_video_feat.npy')

# Check the original shape
print("Original shape:", original_data.shape)

# Reshape the data to (19738, 3072)
reshaped_data = original_data.reshape(19738, -1)

# Check the new shape
print("Reshaped shape:", reshaped_data.shape)

# Save the reshaped array to a new .npy file
np.save('oral_video_feat_reshaped.npy', reshaped_data)

print("Reshaped data saved successfully.")
# Out:
# Original shape: (19738, 3, 1024)
# Reshaped shape: (19738, 3072)
# Reshaped data saved successfully.
